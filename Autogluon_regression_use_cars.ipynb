# %% [markdown]
# # **Use Cars Regression - Playground Series PS4S9**
#
# - RMSE 20 hours training L5 models
#  with a L6 weight ensemble.
# - MAE 4 hours training L2 models with L3 weight ensemble.

# %% [markdown]
# # **Setup**

# %%
# %%capture

# AutoGluon is a SOTA AutoML framework
# %pip install -q setuptools wheel autogluon.tabular[all,skex] dask[dataframe]
# %pip install -U -q ipywidgets cloudpickle==2.2.1

# %%
# %%capture

# # LightGBM GPU instalation (restart after installing)
# ! git clone --recursive https://github.com/Microsoft/LightGBM

# #You can run this oneliner which will build and compile LightGBM with GPU enabled in colab:
# ! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
# !mkdir -p /etc/OpenCL/vendors && echo "libnvidia-opencl.so.1" > /etc/OpenCL/vendors/nvidia.icd

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import os
import cloudpickle
import re
from autogluon.tabular import TabularDataset, TabularPredictor
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = os.getenv('DATA_FOLDER_PATH', '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/')

train_data = TabularDataset(os.path.join(base_path, 'train.csv'))
test_data = TabularDataset(os.path.join(base_path, 'test.csv'))
use_cars = TabularDataset(os.path.join(base_path, 'used_cars.csv'))

# %%
train_data.drop(columns=['id'], inplace=True)
test_data.drop(columns=['id'], inplace=True)
use_cars[['milage', 'price']] = use_cars[['milage', 'price']].map(lambda x: int(''.join(re.findall(r'\d+', x))))
train = pd.concat([train_data, use_cars], ignore_index=True)

# %%
submission = TabularDataset(os.path.join(base_path, 'sample_submission.csv'))

# %% [markdown]
# # **Preprocessing and Feature engineering**
#
# Inspire by this [kaggle notebooks](https://www.kaggle.com/code/swandipsingha/autoglun-lgbm-and-nn)

# %%
def extract_age_features(df):
    """
    Extracts age-related features from the dataset.
    """
    current_year = 2024
    df['Vehicle_Age'] = current_year - df['model_year']
    # Avoid division by zero
    df['Vehicle_Age'] = df['Vehicle_Age'].replace(0, 1)
    df['Mileage_per_Year'] = df['milage'] / df['Vehicle_Age']
    df['milage_with_age'] = df.groupby('Vehicle_Age')['milage'].transform('mean')
    df['Mileage_per_Year_with_age'] = df.groupby('Vehicle_Age')['Mileage_per_Year'].transform('mean')
    return df

def extract_other_features(df):
    """
    Extracts additional features such as luxury brand indicator.
    """
    luxury_brands = [
        'Mercedes-Benz', 'BMW', 'Audi', 'Porsche', 'Land', 'Lexus', 'Jaguar',
        'Bentley', 'Maserati', 'Lamborghini', 'Rolls-Royce', 'Ferrari',
        'McLaren', 'Aston', 'Maybach'
    ]
    df['Is_Luxury_Brand'] = df['brand'].apply(lambda x: 1 if x in luxury_brands else 0)
    return df

def update(df):
    """
    Handles rare categories by grouping them under 'noise' and fills missing values.
    Converts specified columns to categorical types.
    """
    threshold = 100
    categorical_columns = [
        'brand', 'model', 'fuel_type', 'engine',
        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title'
    ]
    rare_columns = ['model', 'engine', 'transmission', 'ext_col', 'int_col']

    for col in rare_columns:
        freq = df[col].value_counts()
        df[col] = df[col].apply(lambda x: x if freq[x] >= threshold else 'noise')

    for col in categorical_columns:
        df[col] = df[col].fillna('missing')
        df[col] = df[col].astype('category')

    return df

# Apply feature engineering to both training and test sets
train = extract_age_features(train)
train = extract_other_features(train)
train = update(train)

test = extract_age_features(test_data)
test = extract_other_features(test_data)
test = update(test)

# %% [markdown]
# # **Autogluon Training RMSE**

# %%
# Setting up
eval_metric = 'rmse'
label = 'price'
problem_type='regression'

# Models to exclude
excluded_model_types = ['KNN']

# Initialize the TabularPredictor
predictor = TabularPredictor(label=label, eval_metric=eval_metric, problem_type=problem_type,
                             path = os.path.join(base_path, "Autogluon/202409_20hr_train"))

# Fit the model
predictor.fit(train_data=train,
              time_limit=3600*20,
              presets="best_quality",
              excluded_model_types=excluded_model_types,
              num_bag_folds=5,
              num_bag_sets = 10,
              num_stack_levels=4,
              full_weighted_ensemble_additionally=True
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          2
# Memory Avail:       11.06 GB / 12.67 GB (87.2%)
# Disk Space Avail:   171.00 GB / 225.83 GB (75.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=4, num_bag_folds=5, num_bag_sets=10
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 18000s of the 72000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-09-27 04:48:58,489	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_20hr_train/ds_sub_fit/sub_fit_ho"
# (_dystack pid=8776) Running DyStack sub-fit ...
# (_dystack pid=8776) Beginning AutoGluon training ... Time limit = 17992s
# (_dystack pid=8776) AutoGluon will save models to "/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_20hr_train/ds_sub_fit/sub_fit_ho"
# (_dystack pid=8776) Train Data Rows:    171148
# (_dystack pid=8776) Train Data Columns: 16
# (_dystack pid=8776) Label Column:       price
# (_dystack pid=8776) Problem Type:       regression
# (_dystack pid=8776) Preprocessing data ...
# (_dystack pid=8776) Using Feature Generators to preprocess the data ...
# (_dystack pid=8776) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=8776) 	Available Memory:                    10843.40 MB
# (_dystack pid=8776) 	Train Data (Original)  Memory Usage: 11.02 MB (0.1% of available memory)
# (_dystack pid=8776) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=8776) 	Stage 1 Generators:
# (_dystack pid=8776) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=8776) 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=8776) 	Stage 2 Generators:
# (_dystack pid=8776) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=8776) 	Stage 3 Generators:
# (_dystack pid=8776) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=8776) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=8776) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=8776) 	Stage 4 Generators:
# (_dystack pid=8776) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=8776) 	Stage 5 Generators:
# (_dystack pid=8776) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=8776) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=8776) 		('category', []) : 9 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# (_dystack pid=8776) 		('float', [])    : 3 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age']
# (_dystack pid=8776) 		('int', [])      : 4 | ['model_year', 'milage', 'Vehicle_Age', 'Is_Luxury_Brand']
# (_dystack pid=8776) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=8776) 		('category', [])  : 8 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# (_dystack pid=8776) 		('float', [])     : 3 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age']
# (_dystack pid=8776) 		('int', [])       : 3 | ['model_year', 'milage', 'Vehicle_Age']
# (_dystack pid=8776) 		('int', ['bool']) : 2 | ['clean_title', 'Is_Luxury_Brand']
# (_dystack pid=8776) 	0.5s = Fit runtime
# (_dystack pid=8776) 	16 features in original data used to generate 16 features in processed data.
# (_dystack pid=8776) 	Train Data (Processed) Memory Usage: 9.80 MB (0.1% of available memory)
# (_dystack pid=8776) Data preprocessing and feature engineering runtime = 0.49s ...
# (_dystack pid=8776) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=8776) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=8776) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=8776) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=8776) User-specified model hyperparameters to be fit:
# (_dystack pid=8776) {
# (_dystack pid=8776) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=8776) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=8776) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=8776) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=8776) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=8776) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=8776) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=8776) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=8776) }
# (_dystack pid=8776) AutoGluon will fit 5 stack levels (L1 to L5) ...
# (_dystack pid=8776) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=8776) Fitting 106 L1 models ...
# (_dystack pid=8776) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 4796.5s of the 17991.36s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.70%)
# (_dystack pid=8776) 	-73147.7718	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	29.4s	 = Training   runtime
# (_dystack pid=8776) 	3.15s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBM_BAG_L1 ... Training model for up to 4761.11s of the 17955.97s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.72%)
# (_dystack pid=8776) 	-73440.4751	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	27.01s	 = Training   runtime
# (_dystack pid=8776) 	1.93s	 = Validation runtime
# (_dystack pid=8776) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 4730.43s of the 17925.3s of remaining time.
# (_dystack pid=8776) 	-77956.6522	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	351.33s	 = Training   runtime
# (_dystack pid=8776) 	8.55s	 = Validation runtime
# (_dystack pid=8776) Fitting model: CatBoost_BAG_L1 ... Training model for up to 4366.34s of the 17561.21s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.75%)
# (_dystack pid=8776) 	-73203.6093	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	778.07s	 = Training   runtime
# (_dystack pid=8776) 	2.28s	 = Validation runtime
# (_dystack pid=8776) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 3584.95s of the 16779.81s of remaining time.
# (_dystack pid=8776) 	-76929.8361	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	120.18s	 = Training   runtime
# (_dystack pid=8776) 	8.21s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3450.7s of the 16645.56s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.23%)
# (_dystack pid=8776) 	-73338.0108	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	1076.89s	 = Training   runtime
# (_dystack pid=8776) 	5.37s	 = Validation runtime
# (_dystack pid=8776) Fitting model: XGBoost_BAG_L1 ... Training model for up to 2369.57s of the 15564.43s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.02%)
# (_dystack pid=8776) 	-74150.7063	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	719.73s	 = Training   runtime
# (_dystack pid=8776) 	2.27s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1645.69s of the 14840.55s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.69%)
# (_dystack pid=8776) 	-73705.853	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	956.93s	 = Training   runtime
# (_dystack pid=8776) 	2.04s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 685.18s of the 13880.04s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.85%)
# (_dystack pid=8776) 	-74009.4704	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	29.82s	 = Training   runtime
# (_dystack pid=8776) 	1.62s	 = Validation runtime
# (_dystack pid=8776) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 649.78s of the 13844.64s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.75%)
# (_dystack pid=8776) 	-73199.4226	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	340.42s	 = Training   runtime
# (_dystack pid=8776) 	1.4s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 302.99s of the 13497.85s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.69%)
# (_dystack pid=8776) 	-73830.8684	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	260.88s	 = Training   runtime
# (_dystack pid=8776) 	3.64s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 37.18s of the 13232.04s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.75%)
# (_dystack pid=8776) 	-73405.6481	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	41.08s	 = Training   runtime
# (_dystack pid=8776) 	6.86s	 = Validation runtime
# (_dystack pid=8776) Completed 1/10 k-fold bagging repeats ...
# (_dystack pid=8776) Fitting model: WeightedEnsemble_L2 ... Training model for up to 479.65s of the 13184.55s of remaining time.
# (_dystack pid=8776) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.25, 'NeuralNetFastAI_BAG_L1': 0.25, 'CatBoost_r177_BAG_L1': 0.167, 'CatBoost_BAG_L1': 0.125, 'RandomForestMSE_BAG_L1': 0.083, 'NeuralNetTorch_BAG_L1': 0.083, 'ExtraTreesMSE_BAG_L1': 0.042}
# (_dystack pid=8776) 	-72884.3271	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	0.81s	 = Training   runtime
# (_dystack pid=8776) 	0.0s	 = Validation runtime
# (_dystack pid=8776) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=8776) Fitting 106 L2 models ...
# (_dystack pid=8776) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 4393.43s of the 13183.23s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.18%)
# (_dystack pid=8776) 	-72995.7144	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	30.04s	 = Training   runtime
# (_dystack pid=8776) 	1.01s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBM_BAG_L2 ... Training model for up to 4359.54s of the 13149.35s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.21%)
# (_dystack pid=8776) 	-73224.0692	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	29.56s	 = Training   runtime
# (_dystack pid=8776) 	1.24s	 = Validation runtime
# (_dystack pid=8776) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 4326.1s of the 13115.9s of remaining time.
# (_dystack pid=8776) 	-74905.0517	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	1972.43s	 = Training   runtime
# (_dystack pid=8776) 	11.8s	 = Validation runtime
# (_dystack pid=8776) Fitting model: CatBoost_BAG_L2 ... Training model for up to 2337.27s of the 11127.08s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.27%)
# (_dystack pid=8776) 	-72919.1734	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	291.97s	 = Training   runtime
# (_dystack pid=8776) 	0.6s	 = Validation runtime
# (_dystack pid=8776) Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 2041.26s of the 10831.07s of remaining time.
# (_dystack pid=8776) 	-74362.7757	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	248.43s	 = Training   runtime
# (_dystack pid=8776) 	8.01s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1780.74s of the 10570.54s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.01%)
# (_dystack pid=8776) 	-73076.3561	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	868.31s	 = Training   runtime
# (_dystack pid=8776) 	6.5s	 = Validation runtime
# (_dystack pid=8776) Fitting model: XGBoost_BAG_L2 ... Training model for up to 906.66s of the 9696.47s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.68%)
# (_dystack pid=8776) 	-73416.6086	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	527.44s	 = Training   runtime
# (_dystack pid=8776) 	3.03s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 373.1s of the 9162.9s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.12%)
# (_dystack pid=8776) 	-73532.3842	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	308.8s	 = Training   runtime
# (_dystack pid=8776) 	5.76s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 59.0s of the 8848.8s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.40%)
# (_dystack pid=8776) 	-73718.6282	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	37.84s	 = Training   runtime
# (_dystack pid=8776) 	2.53s	 = Validation runtime
# (_dystack pid=8776) Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 15.38s of the 8805.19s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.27%)
# (_dystack pid=8776) 	-77981.1252	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	17.12s	 = Training   runtime
# (_dystack pid=8776) 	0.27s	 = Validation runtime
# (_dystack pid=8776) Completed 1/10 k-fold bagging repeats ...
# (_dystack pid=8776) Fitting model: WeightedEnsemble_L3 ... Training model for up to 439.34s of the 8780.84s of remaining time.
# (_dystack pid=8776) 	Ensemble Weights: {'CatBoost_BAG_L2': 0.44, 'LightGBMXT_BAG_L2': 0.2, 'NeuralNetFastAI_BAG_L2': 0.2, 'ExtraTreesMSE_BAG_L2': 0.08, 'RandomForestMSE_BAG_L2': 0.04, 'NeuralNetTorch_BAG_L2': 0.04}
# (_dystack pid=8776) 	-72866.292	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	0.58s	 = Training   runtime
# (_dystack pid=8776) 	0.0s	 = Validation runtime
# (_dystack pid=8776) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=8776) Fitting 106 L3 models ...
# (_dystack pid=8776) Fitting model: LightGBMXT_BAG_L3 ... Training model for up to 3901.32s of the 8780.02s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.11%)
# (_dystack pid=8776) 	-73069.1935	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	29.73s	 = Training   runtime
# (_dystack pid=8776) 	1.69s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBM_BAG_L3 ... Training model for up to 3868.06s of the 8746.76s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.13%)
# (_dystack pid=8776) 	-73414.9878	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	27.65s	 = Training   runtime
# (_dystack pid=8776) 	1.6s	 = Validation runtime
# (_dystack pid=8776) Fitting model: RandomForestMSE_BAG_L3 ... Training model for up to 3836.32s of the 8715.02s of remaining time.
# (_dystack pid=8776) 	-75111.8354	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	1682.37s	 = Training   runtime
# (_dystack pid=8776) 	11.29s	 = Validation runtime
# (_dystack pid=8776) Fitting model: CatBoost_BAG_L3 ... Training model for up to 2135.59s of the 7014.29s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.21%)
# (_dystack pid=8776) 	-72902.7965	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	216.41s	 = Training   runtime
# (_dystack pid=8776) 	0.89s	 = Validation runtime
# (_dystack pid=8776) Fitting model: ExtraTreesMSE_BAG_L3 ... Training model for up to 1914.72s of the 6793.42s of remaining time.
# (_dystack pid=8776) 	-74404.0491	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	210.31s	 = Training   runtime
# (_dystack pid=8776) 	9.39s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetFastAI_BAG_L3 ... Training model for up to 1688.5s of the 6567.2s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.95%)
# (_dystack pid=8776) 	-73019.3641	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	1038.24s	 = Training   runtime
# (_dystack pid=8776) 	7.35s	 = Validation runtime
# (_dystack pid=8776) Fitting model: XGBoost_BAG_L3 ... Training model for up to 645.84s of the 5524.54s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.64%)
# (_dystack pid=8776) 	-73477.1122	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	442.81s	 = Training   runtime
# (_dystack pid=8776) 	2.57s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetTorch_BAG_L3 ... Training model for up to 196.12s of the 5074.82s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.10%)
# (_dystack pid=8776) 	-73784.3513	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	176.57s	 = Training   runtime
# (_dystack pid=8776) 	4.75s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 14.51s of the 4893.21s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.36%)
# (_dystack pid=8776) 	-75081.0922	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	24.77s	 = Training   runtime
# (_dystack pid=8776) 	0.65s	 = Validation runtime
# (_dystack pid=8776) Completed 1/10 k-fold bagging repeats ...
# (_dystack pid=8776) Fitting model: WeightedEnsemble_L4 ... Training model for up to 390.13s of the 4859.41s of remaining time.
# (_dystack pid=8776) 	Ensemble Weights: {'CatBoost_BAG_L3': 0.714, 'NeuralNetFastAI_BAG_L3': 0.286}
# (_dystack pid=8776) 	-72880.2502	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	0.43s	 = Training   runtime
# (_dystack pid=8776) 	0.0s	 = Validation runtime
# (_dystack pid=8776) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=8776) Fitting 106 L4 models ...
# (_dystack pid=8776) Fitting model: LightGBMXT_BAG_L4 ... Training model for up to 3238.46s of the 4858.77s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.12%)
# (_dystack pid=8776) 	-73088.6467	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	27.82s	 = Training   runtime
# (_dystack pid=8776) 	1.14s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBM_BAG_L4 ... Training model for up to 3204.76s of the 4825.06s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.15%)
# (_dystack pid=8776) 	-73359.3098	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	26.22s	 = Training   runtime
# (_dystack pid=8776) 	0.83s	 = Validation runtime
# (_dystack pid=8776) Fitting model: RandomForestMSE_BAG_L4 ... Training model for up to 3172.37s of the 4792.67s of remaining time.
# (_dystack pid=8776) 	-75194.6931	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	1576.85s	 = Training   runtime
# (_dystack pid=8776) 	11.06s	 = Validation runtime
# (_dystack pid=8776) Fitting model: CatBoost_BAG_L4 ... Training model for up to 1577.86s of the 3198.17s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.17%)
# (_dystack pid=8776) 	-72941.5121	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	245.77s	 = Training   runtime
# (_dystack pid=8776) 	0.71s	 = Validation runtime
# (_dystack pid=8776) Fitting model: ExtraTreesMSE_BAG_L4 ... Training model for up to 1328.17s of the 2948.47s of remaining time.
# (_dystack pid=8776) 	-74447.694	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	201.69s	 = Training   runtime
# (_dystack pid=8776) 	9.37s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 1111.81s of the 2732.12s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.89%)
# (_dystack pid=8776) 	-73125.8157	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	577.53s	 = Training   runtime
# (_dystack pid=8776) 	7.89s	 = Validation runtime
# (_dystack pid=8776) Fitting model: XGBoost_BAG_L4 ... Training model for up to 529.72s of the 2150.03s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.58%)
# (_dystack pid=8776) 	-73748.8965	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	373.91s	 = Training   runtime
# (_dystack pid=8776) 	1.98s	 = Validation runtime
# (_dystack pid=8776) Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 149.78s of the 1770.09s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.06%)
# (_dystack pid=8776) 	-73714.9893	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	139.52s	 = Training   runtime
# (_dystack pid=8776) 	4.68s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 5.94s of the 1626.24s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.32%)
# (_dystack pid=8776) 	-78325.6365	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	19.63s	 = Training   runtime
# (_dystack pid=8776) 	0.29s	 = Validation runtime
# (_dystack pid=8776) Completed 1/10 k-fold bagging repeats ...
# (_dystack pid=8776) Fitting model: WeightedEnsemble_L5 ... Training model for up to 360.0s of the 1599.76s of remaining time.
# (_dystack pid=8776) 	Ensemble Weights: {'CatBoost_BAG_L4': 0.688, 'NeuralNetFastAI_BAG_L4': 0.188, 'LightGBMXT_BAG_L4': 0.062, 'RandomForestMSE_BAG_L4': 0.062}
# (_dystack pid=8776) 	-72917.7618	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	0.48s	 = Training   runtime
# (_dystack pid=8776) 	0.0s	 = Validation runtime
# (_dystack pid=8776) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=8776) Fitting 106 L5 models ...
# (_dystack pid=8776) Fitting model: LightGBMXT_BAG_L5 ... Training model for up to 1599.17s of the 1598.92s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.13%)
# (_dystack pid=8776) 	-73129.8069	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	30.06s	 = Training   runtime
# (_dystack pid=8776) 	1.35s	 = Validation runtime
# (_dystack pid=8776) Fitting model: LightGBM_BAG_L5 ... Training model for up to 1564.89s of the 1564.64s of remaining time.
# (_dystack pid=8776) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.15%)
# (_dystack pid=8776) 	-73406.2272	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	30.02s	 = Training   runtime
# (_dystack pid=8776) 	1.02s	 = Validation runtime
# (_dystack pid=8776) Fitting model: RandomForestMSE_BAG_L5 ... Training model for up to 1530.61s of the 1530.37s of remaining time.
# (_dystack pid=8776) 	Warning: Reducing model 'n_estimators' from 300 -> 288 due to low time. Expected time usage reduced from 1591.6s -> 1530.6s...
# (_dystack pid=8776) 	-75504.8758	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	1534.14s	 = Training   runtime
# (_dystack pid=8776) 	10.23s	 = Validation runtime
# (_dystack pid=8776) Completed 1/10 k-fold bagging repeats ...
# (_dystack pid=8776) Fitting model: WeightedEnsemble_ALL_L6 ... Training model for up to 360.0s of the -20.68s of remaining time.
# (_dystack pid=8776) 	Ensemble Weights: {'CatBoost_BAG_L2': 0.2, 'CatBoost_BAG_L3': 0.16, 'NeuralNetFastAI_BAG_L3': 0.16, 'NeuralNetFastAI_BAG_L1': 0.12, 'LightGBMXT_BAG_L2': 0.12, 'ExtraTreesMSE_BAG_L2': 0.08, 'NeuralNetFastAI_BAG_L2': 0.08, 'NeuralNetTorch_BAG_L1': 0.04, 'CatBoost_r177_BAG_L1': 0.04}
# (_dystack pid=8776) 	-72844.5028	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	0.7s	 = Training   runtime
# (_dystack pid=8776) 	0.0s	 = Validation runtime
# (_dystack pid=8776) Fitting model: WeightedEnsemble_L6 ... Training model for up to 360.0s of the -21.5s of remaining time.
# (_dystack pid=8776) 	Ensemble Weights: {'LightGBMXT_BAG_L5': 0.818, 'LightGBM_BAG_L5': 0.091, 'RandomForestMSE_BAG_L5': 0.091}
# (_dystack pid=8776) 	-73099.9796	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=8776) 	0.15s	 = Training   runtime
# (_dystack pid=8776) 	0.0s	 = Validation runtime
# (_dystack pid=8776) AutoGluon training complete, total runtime = 18013.73s ... Best model: WeightedEnsemble_ALL_L6 | Estimated inference throughput: 510.5 rows/s (34230 batch size)
# (_dystack pid=8776) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_20hr_train/ds_sub_fit/sub_fit_ho")
# (_dystack pid=8776) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                         model  score_holdout     score_val              eval_metric  pred_time_test  pred_time_val      fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         WeightedEnsemble_L5  -69298.937437 -72917.761773  root_mean_squared_error       82.338103     149.046123  15341.004066                 0.009159                0.004293           0.484272            5       True         44
# 1     WeightedEnsemble_ALL_L6  -69311.439874 -72844.502814  root_mean_squared_error       54.287712      96.309258  10319.019869                 0.015634                0.003195           0.697691            6       True         48
# 2      NeuralNetFastAI_BAG_L4  -69315.780899 -73125.815691  root_mean_squared_error       75.219923     136.128395  13490.075337                 3.494672                7.892428         577.534146            4       True         40
# 3             CatBoost_BAG_L4  -69326.785323 -72941.512128  root_mean_squared_error       72.040140     128.948897  13158.315687                 0.314889                0.712930         245.774496            4       True         38
# 4         WeightedEnsemble_L3  -69327.702851 -72866.292008  root_mean_squared_error       49.300719      81.001094   8452.290849                 0.008999                0.003846           0.576979            3       True         24
# 5             LightGBM_BAG_L2  -69334.511479 -73224.069192  root_mean_squared_error       31.739928      48.557479   4761.289463                 0.389471                1.241042          29.561754            2       True         15
# 6         WeightedEnsemble_L4  -69338.750603 -72880.250207  root_mean_squared_error       54.281032      96.309970  10318.747570                 0.008954                0.003907           0.425392            4       True         34
# 7             CatBoost_BAG_L3  -69352.451188 -72902.796458  root_mean_squared_error       51.622603      88.953571   9280.083623                 0.310448                0.885243         216.413728            3       True         28
# 8      NeuralNetFastAI_BAG_L3  -69365.216140 -73019.364138  root_mean_squared_error       53.961630      95.420820  10101.908450                 2.649474                7.352492        1038.238555            3       True         30
# 9             CatBoost_BAG_L2  -69373.841339 -72919.173418  root_mean_squared_error       31.902987      47.917649   5023.697570                 0.552530                0.601212         291.969861            2       True         17
# 10        WeightedEnsemble_L6  -69383.703527 -73099.979648  root_mean_squared_error       96.976083     178.789712  17695.854998                 0.017078                0.002845           0.146541            6       True         49
# 11          LightGBMXT_BAG_L2  -69389.769507 -72995.714393  root_mean_squared_error       31.843566      48.328658   4761.765943                 0.493109                1.012221          30.038234            2       True         14
# 12          LightGBMXT_BAG_L5  -69394.155825 -73129.806895  root_mean_squared_error       91.391377     167.532945  16131.553005                 0.494690                1.354151          30.062881            5       True         45
# 13          LightGBMXT_BAG_L4  -69400.027703 -73088.646658  root_mean_squared_error       72.431627     129.379515  12940.365007                 0.706375                1.143548          27.823816            4       True         35
# 14     NeuralNetFastAI_BAG_L2  -69416.441162 -73076.356114  root_mean_squared_error       33.719865      53.819194   5600.041293                 2.369408                6.502757         868.313584            2       True         19
# 15          LightGBMXT_BAG_L3  -69442.784761 -73069.193493  root_mean_squared_error       51.765258      89.756071   9093.403848                 0.453103                1.687744          29.733953            3       True         25
# 16            LightGBM_BAG_L4  -69444.634948 -73359.309819  root_mean_squared_error       72.167349     129.063010  12938.760102                 0.442098                0.827043          26.218911            4       True         36
# 17        WeightedEnsemble_L2  -69452.618487 -72884.327102  root_mean_squared_error       24.887646      30.999779   3654.020214                 0.011297                0.003822           0.810992            2       True         13
# 18     NeuralNetFastAI_BAG_L1  -69453.882872 -73338.010774  root_mean_squared_error        2.926178       5.371799   1076.885189                 2.926178                5.371799        1076.885189            1       True          6
# 19            LightGBM_BAG_L3  -69476.549973 -73414.987844  root_mean_squared_error       51.613532      89.672144   9091.324525                 0.301376                1.603817          27.654630            3       True         26
# 20            LightGBM_BAG_L5  -69478.512496 -73406.227182  root_mean_squared_error       91.287591     167.198365  16131.510132                 0.390903                1.019572          30.020008            5       True         46
# 21             XGBoost_BAG_L2  -69478.797084 -73416.608639  root_mean_squared_error       32.154557      50.343884   5259.169080                 0.804101                3.027447         527.441371            2       True         20
# 22            LightGBM_BAG_L1  -69514.572524 -73440.475051  root_mean_squared_error        0.593873       1.933596     27.005048                 0.593873                1.933596          27.005048            1       True          2
# 23          LightGBMXT_BAG_L1  -69528.292059 -73147.771809  root_mean_squared_error        1.953429       3.150537     29.402008                 1.953429                3.150537          29.402008            1       True          1
# 24       LightGBMLarge_BAG_L2  -69528.897857 -73718.628165  root_mean_squared_error       32.088875      49.849626   4769.564310                 0.738418                2.533189          37.836601            2       True         22
# 25       LightGBM_r131_BAG_L1  -69543.268990 -73405.648057  root_mean_squared_error        2.261379       6.861807     41.082648                 2.261379                6.861807          41.082648            1       True         12
# 26       CatBoost_r177_BAG_L1  -69547.575235 -73199.422615  root_mean_squared_error        1.177539       1.395954    340.416849                 1.177539                1.395954         340.416849            1       True         10
# 27             XGBoost_BAG_L3  -69563.409346 -73477.112224  root_mean_squared_error       51.913144      90.634407   9506.479893                 0.600988                2.566079         442.809998            3       True         31
# 28            CatBoost_BAG_L1  -69578.112038 -73203.609305  root_mean_squared_error        1.312710       2.277821    778.066591                 1.312710                2.277821         778.066591            1       True          4
# 29             XGBoost_BAG_L4  -69591.253601 -73748.896485  root_mean_squared_error       72.867280     130.211060  13286.448228                 1.142028                1.975092         373.907037            4       True         41
# 30      NeuralNetTorch_BAG_L2  -69801.999676 -73532.384186  root_mean_squared_error       32.712543      53.071799   5040.531131                 1.362086                5.755362         308.803421            2       True         21
# 31      NeuralNetTorch_BAG_L4  -69897.158148 -73714.989302  root_mean_squared_error       73.622560     132.918368  13052.061931                 1.897309                4.682401         139.520740            4       True         42
# 32       LightGBMLarge_BAG_L1  -69899.023857 -74009.470436  root_mean_squared_error        1.210409       1.615488     29.819370                 1.210409                1.615488          29.819370            1       True          9
# 33      NeuralNetTorch_BAG_L3  -69952.441489 -73784.351255  root_mean_squared_error       53.493460      92.816319   9240.238513                 2.181304                4.747992         176.568619            3       True         32
# 34  NeuralNetTorch_r79_BAG_L1  -70084.842817 -73830.868444  root_mean_squared_error        1.274655       3.635667    260.881642                 1.274655                3.635667         260.881642            1       True         11
# 35      NeuralNetTorch_BAG_L1  -70093.877957 -73705.852965  root_mean_squared_error        1.884156       2.040246    956.926866                 1.884156                2.040246         956.926866            1       True          8
# 36     RandomForestMSE_BAG_L4  -70098.271887 -75194.693068  root_mean_squared_error       77.813009     139.292923  14489.387335                 6.087757               11.056956        1576.846144            4       True         37
# 37       ExtraTreesMSE_BAG_L4  -70190.225566 -74447.694003  root_mean_squared_error       76.662879     137.602761  13114.234825                 4.937628                9.366794         201.693634            4       True         39
# 38       ExtraTreesMSE_BAG_L2  -70201.887012 -74362.775716  root_mean_squared_error       37.541222      55.325562   4980.155059                 6.190765                8.009125         248.427350            2       True         18
# 39     RandomForestMSE_BAG_L3  -70298.315010 -75111.835412  root_mean_squared_error       59.380713      99.356048  10746.043247                 8.068558               11.287720        1682.373352            3       True         27
# 40             XGBoost_BAG_L1  -70320.162864 -74150.706271  root_mean_squared_error        1.133792       2.273922    719.729779                 1.133792                2.273922         719.729779            1       True          7
# 41       ExtraTreesMSE_BAG_L3  -70392.245287 -74404.049087  root_mean_squared_error       56.590033      97.455291   9273.975245                 5.277878                9.386963         210.305351            3       True         29
# 42       LightGBMLarge_BAG_L3  -70577.742913 -75081.092165  root_mean_squared_error       51.882123      88.717916   9088.443004                 0.569967                0.649589          24.773109            3       True         33
# 43     RandomForestMSE_BAG_L2  -70750.278090 -74905.051711  root_mean_squared_error       38.323822      59.116571   6704.161419                 6.973365               11.800134        1972.433710            2       True         16
# 44     RandomForestMSE_BAG_L5  -70862.876902 -75504.875772  root_mean_squared_error       96.073412     176.413144  17635.625568                 5.176724               10.234351        1534.135444            5       True         47
# 45       CatBoost_r177_BAG_L2  -74215.484016 -77981.125159  root_mean_squared_error       31.438902      47.585839   4748.844009                 0.088445                0.269402          17.116300            2       True         23
# 46       LightGBMLarge_BAG_L4  -74573.979891 -78325.636497  root_mean_squared_error       71.873933     128.521601  12932.171200                 0.148681                0.285634          19.630009            4       True         43
# 47       ExtraTreesMSE_BAG_L1  -75336.726554 -76929.836149  root_mean_squared_error        5.341732       8.209637    120.180074                 5.341732                8.209637         120.180074            1       True          5
# 48     RandomForestMSE_BAG_L1  -75559.609111 -77956.652191  root_mean_squared_error       10.280604       8.549963    351.331644                10.280604                8.549963         351.331644            1       True          3
# 	4	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	18124s	 = DyStack   runtime |	53876s	 = Remaining runtime
# Starting main fit with num_stack_levels=4.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=4)`
# Beginning AutoGluon training ... Time limit = 53876s
# AutoGluon will save models to "/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_20hr_train"
# Train Data Rows:    192542
# Train Data Columns: 16
# Label Column:       price
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9959.15 MB
# 	Train Data (Original)  Memory Usage: 12.39 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 9 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# 		('float', [])    : 3 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age']
# 		('int', [])      : 4 | ['model_year', 'milage', 'Vehicle_Age', 'Is_Luxury_Brand']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 8 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# 		('float', [])     : 3 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age']
# 		('int', [])       : 3 | ['model_year', 'milage', 'Vehicle_Age']
# 		('int', ['bool']) : 2 | ['clean_title', 'Is_Luxury_Brand']
# 	1.1s = Fit runtime
# 	16 features in original data used to generate 16 features in processed data.
# 	Train Data (Processed) Memory Usage: 11.02 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 1.19s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.56%)
# 	-72726.881	 = Validation score   (-root_mean_squared_error)
# 	1335.22s	 = Training   runtime
# 	10.18s	 = Validation runtime
# Fitting model: XGBoost_BAG_L3 ... Training model for up to 6089.81s of the 20720.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.13%)
# 	-72964.8493	 = Validation score   (-root_mean_squared_error)
# 	732.2s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L3 ... Training model for up to 5351.94s of the 19982.97s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.42%)
# 	-73079.698	 = Validation score   (-root_mean_squared_error)
# 	620.28s	 = Training   runtime
# 	6.78s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 4724.4s of the 19355.4s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.77%)
# 	-73334.5599	 = Validation score   (-root_mean_squared_error)
# 	46.17s	 = Training   runtime
# 	1.71s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L3 ... Training model for up to 4670.8s of the 19301.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.61%)
# 	-72462.6232	 = Validation score   (-root_mean_squared_error)
# 	181.03s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L3 ... Training model for up to 4484.32s of the 19115.33s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.47%)
# 	-73140.9879	 = Validation score   (-root_mean_squared_error)
# 	941.27s	 = Training   runtime
# 	5.81s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L3 ... Training model for up to 3537.54s of the 18168.56s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.61%)
# 	-72766.9856	 = Validation score   (-root_mean_squared_error)
# 	70.03s	 = Training   runtime
# 	5.3s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L3 ... Training model for up to 3459.28s of the 18090.3s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.59%)
# 	-73288.3709	 = Validation score   (-root_mean_squared_error)
# 	2427.63s	 = Training   runtime
# 	13.27s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L3 ... Training model for up to 1025.52s of the 15656.54s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.03%)
# 	-72536.6721	 = Validation score   (-root_mean_squared_error)
# 	252.25s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L3 ... Training model for up to 768.51s of the 15399.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.53%)
# 	-72563.6011	 = Validation score   (-root_mean_squared_error)
# 	58.27s	 = Training   runtime
# 	5.94s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L3 ... Training model for up to 705.2s of the 15336.2s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.42%)
# 	-90214.1576	 = Validation score   (-root_mean_squared_error)
# 	571.14s	 = Training   runtime
# 	10.22s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L3 ... Training model for up to 127.48s of the 14758.5s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=3.00%)
# 	-77621.9149	 = Validation score   (-root_mean_squared_error)
# 	111.79s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L3 ... Training model for up to 7.34s of the 14638.36s of remaining time.
# 	Warning: Model is expected to require 376.4s to train, which exceeds the maximum time limit of 7.3s, skipping model...
# 	Time limit exceeded... Skipping ExtraTrees_r42_BAG_L3.
# Fitting model: CatBoost_r137_BAG_L3 ... Training model for up to 1.31s of the 14632.33s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.48%)
# 	Time limit exceeded... Skipping CatBoost_r137_BAG_L3.
# 2024-09-27 20:45:05,811	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Completed 1/10 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 1169.98s of the 14624.75s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L3': 0.68, 'CatBoost_r177_BAG_L3': 0.16, 'LightGBM_r96_BAG_L3': 0.08, 'ExtraTreesMSE_BAG_L3': 0.04, 'LightGBM_r131_BAG_L3': 0.04}
# 	-72430.3435	 = Validation score   (-root_mean_squared_error)
# 	0.55s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L4 models ...
# Fitting model: LightGBMXT_BAG_L4 ... Training model for up to 9746.94s of the 14623.64s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.52%)
# 	-72609.6018	 = Validation score   (-root_mean_squared_error)
# 	35.18s	 = Training   runtime
# 	1.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L4 ... Training model for up to 9704.76s of the 14581.44s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.55%)
# 	-72824.0688	 = Validation score   (-root_mean_squared_error)
# 	36.34s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L4 ... Training model for up to 9663.93s of the 14540.63s of remaining time.
# 	-74928.9371	 = Validation score   (-root_mean_squared_error)
# 	3217.09s	 = Training   runtime
# 	15.8s	 = Validation runtime
# Fitting model: CatBoost_BAG_L4 ... Training model for up to 6427.33s of the 11304.03s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.61%)
# 	-72476.982	 = Validation score   (-root_mean_squared_error)
# 	355.88s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L4 ... Training model for up to 6067.3s of the 10944.0s of remaining time.
# 	-73868.0795	 = Validation score   (-root_mean_squared_error)
# 	323.43s	 = Training   runtime
# 	13.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L4 ... Training model for up to 5726.52s of the 10603.23s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.62%)
# 	-72626.7506	 = Validation score   (-root_mean_squared_error)
# 	1191.16s	 = Training   runtime
# 	7.38s	 = Validation runtime
# Fitting model: XGBoost_BAG_L4 ... Training model for up to 4530.42s of the 9407.12s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.20%)
# 	-72918.0153	 = Validation score   (-root_mean_squared_error)
# 	719.04s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L4 ... Training model for up to 3802.82s of the 8679.52s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.46%)
# 	-73124.5074	 = Validation score   (-root_mean_squared_error)
# 	874.92s	 = Training   runtime
# 	7.07s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 2921.66s of the 7798.36s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.81%)
# 	-73466.1563	 = Validation score   (-root_mean_squared_error)
# 	50.3s	 = Training   runtime
# 	3.7s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L4 ... Training model for up to 2865.92s of the 7742.62s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.64%)
# 	-72512.2421	 = Validation score   (-root_mean_squared_error)
# 	155.19s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L4 ... Training model for up to 2704.86s of the 7581.55s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.49%)
# 	-72996.5283	 = Validation score   (-root_mean_squared_error)
# 	701.65s	 = Training   runtime
# 	8.05s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L4 ... Training model for up to 1997.07s of the 6873.74s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.65%)
# 	-72809.7227	 = Validation score   (-root_mean_squared_error)
# 	66.93s	 = Training   runtime
# 	5.53s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L4 ... Training model for up to 1920.12s of the 6796.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.65%)
# 	-72700.9095	 = Validation score   (-root_mean_squared_error)
# 	1489.85s	 = Training   runtime
# 	12.99s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L4 ... Training model for up to 424.88s of the 5301.58s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.07%)
# 	-72578.0453	 = Validation score   (-root_mean_squared_error)
# 	223.11s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L4 ... Training model for up to 197.47s of the 5074.16s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.57%)
# 	-72564.9607	 = Validation score   (-root_mean_squared_error)
# 	56.13s	 = Training   runtime
# 	6.55s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L4 ... Training model for up to 136.68s of the 5013.37s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.45%)
# 	-91945.2604	 = Validation score   (-root_mean_squared_error)
# 	128.06s	 = Training   runtime
# 	6.48s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L4 ... Training model for up to 1.13s of the 4877.84s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=3.06%)
# 	-78604.6664	 = Validation score   (-root_mean_squared_error)
# 	36.68s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Completed 1/10 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L5 ... Training model for up to 974.69s of the 4834.06s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L4': 0.6, 'NeuralNetFastAI_BAG_L4': 0.08, 'XGBoost_BAG_L4': 0.08, 'NeuralNetFastAI_r191_BAG_L4': 0.08, 'LightGBM_r96_BAG_L4': 0.08, 'LightGBMXT_BAG_L4': 0.04, 'ExtraTreesMSE_BAG_L4': 0.04}
# 	-72460.8668	 = Validation score   (-root_mean_squared_error)
# 	0.83s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L5 models ...
# Fitting model: LightGBMXT_BAG_L5 ... Training model for up to 4833.13s of the 4832.84s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.53%)
# 	-72667.6938	 = Validation score   (-root_mean_squared_error)
# 	35.28s	 = Training   runtime
# 	1.72s	 = Validation runtime
# Fitting model: LightGBM_BAG_L5 ... Training model for up to 4791.22s of the 4790.93s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.57%)
# 	-72911.4976	 = Validation score   (-root_mean_squared_error)
# 	37.23s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L5 ... Training model for up to 4750.1s of the 4749.82s of remaining time.
# 	-75074.4345	 = Validation score   (-root_mean_squared_error)
# 	2988.35s	 = Training   runtime
# 	15.41s	 = Validation runtime
# Fitting model: CatBoost_BAG_L5 ... Training model for up to 1738.75s of the 1738.47s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.64%)
# 	-72511.157	 = Validation score   (-root_mean_squared_error)
# 	318.02s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L5 ... Training model for up to 1413.1s of the 1412.82s of remaining time.
# 	-74020.7833	 = Validation score   (-root_mean_squared_error)
# 	315.13s	 = Training   runtime
# 	12.72s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L5 ... Training model for up to 1079.53s of the 1079.25s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.61%)
# 	-72695.0593	 = Validation score   (-root_mean_squared_error)
# 	877.57s	 = Training   runtime
# 	7.59s	 = Validation runtime
# Fitting model: XGBoost_BAG_L5 ... Training model for up to 193.89s of the 193.6s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=2.15%)
# 	-73720.17	 = Validation score   (-root_mean_squared_error)
# 	172.16s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L5 ... Training model for up to 16.2s of the 15.91s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=1.43%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L5.
# 2024-09-28 00:48:55,435	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Completed 1/10 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_ALL_L6 ... Training model for up to 483.31s of the -6.28s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L3': 0.429, 'CatBoost_r9_BAG_L2': 0.286, 'NeuralNetFastAI_BAG_L2': 0.143, 'CatBoost_BAG_L4': 0.095, 'XGBoost_BAG_L4': 0.048}
# 	-72403.7013	 = Validation score   (-root_mean_squared_error)
# 	0.76s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L6 ... Training model for up to 483.31s of the -7.19s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L5': 0.8, 'NeuralNetFastAI_BAG_L5': 0.12, 'LightGBMXT_BAG_L5': 0.04, 'ExtraTreesMSE_BAG_L5': 0.04}
# 	-72503.8694	 = Validation score   (-root_mean_squared_error)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 53884.03s ... Best model: WeightedEnsemble_ALL_L6 | Estimated inference throughput: 149.7 rows/s (38509 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_20hr_train")

# %%
predictor = TabularPredictor.load(os.path.join(base_path, "Autogluon/202409_20hr_train"))

# %%
leaderboard_test = predictor.leaderboard()
leaderboard_test
# Out:
#                         model     score_val              eval_metric  \
# 0     WeightedEnsemble_ALL_L6 -72403.701301  root_mean_squared_error
# 1         WeightedEnsemble_L3 -72424.331896  root_mean_squared_error
# 2         WeightedEnsemble_L4 -72430.343493  root_mean_squared_error
# 3             CatBoost_BAG_L3 -72436.880165  root_mean_squared_error
# 4         WeightedEnsemble_L5 -72460.866840  root_mean_squared_error
# ..                        ...           ...                      ...
# 81         XGBoost_r33_BAG_L4 -78604.666388  root_mean_squared_error
# 82  NeuralNetTorch_r22_BAG_L3 -90214.157608  root_mean_squared_error
# 83  NeuralNetTorch_r22_BAG_L1 -90214.235535  root_mean_squared_error
# 84  NeuralNetTorch_r22_BAG_L2 -90214.252639  root_mean_squared_error
# 85  NeuralNetTorch_r22_BAG_L4 -91945.260419  root_mean_squared_error
#
#     pred_time_val      fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0      328.590529  39879.135358                0.003205           0.762355
# 1      153.660733  16755.988870                0.004543           0.624946
# 2      254.084535  28436.112292                0.003482           0.552062
# 3      228.950053  27780.211033                1.271147         535.711881
# 4      369.968760  42974.950444                0.004268           0.832023
# ..            ...           ...                     ...                ...
# 81     327.570339  38840.132060                1.404315          36.678396
# 82     237.903558  27815.637030               10.224651         571.137878
# 83       6.057364   1020.770602                6.057364        1020.770602
# 84     132.966143  14888.305473                9.326166         668.090714
# 85     332.644267  38931.510752                6.478243         128.057088
#
#     stack_level  can_infer  fit_order
# 0             6       True         85
# 1             3       True         41
# 2             4       True         59
# 3             3       True         45
# 4             5       True         77
# ..          ...        ...        ...
# 81            4       True         76
# 82            3       True         57
# 83            1       True         16
# 84            2       True         39
# 85            4       True         75
#
# [86 rows x 10 columns]

# %% [markdown]
# ## **Submission**

# %%
leaderboard_test.head(10)
# Out:
#                      model     score_val              eval_metric  \
# 0  WeightedEnsemble_ALL_L6 -72403.701301  root_mean_squared_error
# 1      WeightedEnsemble_L3 -72424.331896  root_mean_squared_error
# 2      WeightedEnsemble_L4 -72430.343493  root_mean_squared_error
# 3          CatBoost_BAG_L3 -72436.880165  root_mean_squared_error
# 4      WeightedEnsemble_L5 -72460.866840  root_mean_squared_error
# 5     CatBoost_r177_BAG_L3 -72462.623174  root_mean_squared_error
# 6          CatBoost_BAG_L4 -72476.981999  root_mean_squared_error
# 7       CatBoost_r9_BAG_L2 -72484.676300  root_mean_squared_error
# 8      WeightedEnsemble_L2 -72488.901868  root_mean_squared_error
# 9      WeightedEnsemble_L6 -72503.869436  root_mean_squared_error
#
#    pred_time_val      fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0     328.590529  39879.135358                0.003205           0.762355
# 1     153.660733  16755.988870                0.004543           0.624946
# 2     254.084535  28436.112292                0.003482           0.552062
# 3     228.950053  27780.211033                1.271147         535.711881
# 4     369.968760  42974.950444                0.004268           0.832023
# 5     228.253683  27425.524631                0.574776         181.025479
# 6     326.987309  39159.329232                0.821285         355.875569
# 7     125.345320  14504.054593                1.705343         283.839834
# 8      69.255063   7656.946847                0.005305           1.217805
# 9     443.498913  50010.659121                0.003664           0.297196
#
#    stack_level  can_infer  fit_order
# 0            6       True         85
# 1            3       True         41
# 2            4       True         59
# 3            3       True         45
# 4            5       True         77
# 5            3       True         51
# 6            4       True         63
# 7            2       True         37
# 8            2       True         23
# 9            6       True         86

# %%
sub_weigth_ensemble_L6_all = submission.copy()
sub_weigth_ensemble_L6_all['price'] = predictor.predict(test_data, model='WeightedEnsemble_ALL_L6')
sub_weigth_ensemble_L6_all.to_csv(os.path.join(base_path, 'autogluon_weigth_ensemble_L6_all.csv'), index=False)

# %%
sub_weigth_ensemble_L6 = submission.copy()
sub_weigth_ensemble_L6['price'] = predictor.predict(test_data, model='WeightedEnsemble_L6')
sub_weigth_ensemble_L6.to_csv(os.path.join(base_path, 'autogluon_weigth_ensemble_L6.csv'), index=False)

# %%
sub_weigth_ensemble_L3 = submission.copy()
sub_weigth_ensemble_L3['price'] = predictor.predict(test_data, model='WeightedEnsemble_L3')
sub_weigth_ensemble_L3.to_csv(os.path.join(base_path, 'autogluon_weigth_ensemble_L3.csv'), index=False)

# %%
sub_weigth_ensemble_L4 = submission.copy()
sub_weigth_ensemble_L4['price'] = predictor.predict(test_data, model='WeightedEnsemble_L4')
sub_weigth_ensemble_L4.to_csv(os.path.join(base_path, 'autogluon_weigth_ensemble_L4.csv'), index=False)

# %%
sub_catboost_bag_L3 = submission.copy()
sub_catboost_bag_L3['price'] = predictor.predict(test_data, model='CatBoost_BAG_L3')
sub_catboost_bag_L3.to_csv(os.path.join(base_path, 'autogluon_CatBoost_BAG_L3.csv'), index=False)

# %%
sub_weigth_ensemble_L5 = submission.copy()
sub_weigth_ensemble_L5['price'] = predictor.predict(test_data, model='WeightedEnsemble_L5')
sub_weigth_ensemble_L5.to_csv(os.path.join(base_path, 'autogluon_WeightedEnsemble_L5.csv'), index=False)

# %%
sub_weigth_ensemble_L2 = submission.copy()
sub_weigth_ensemble_L2['price'] = predictor.predict(test_data, model='WeightedEnsemble_L2')
sub_weigth_ensemble_L2.to_csv(os.path.join(base_path, 'autogluon_WeightedEnsemble_L2.csv'), index=False)

# %%
sub_catboost_r177_bag_L3 = submission.copy()
sub_catboost_r177_bag_L3['price'] = predictor.predict(test_data, model='CatBoost_r177_BAG_L3')
sub_catboost_r177_bag_L3.to_csv(os.path.join(base_path, 'autogluon_CatBoost_r177_BAG_L3.csv'), index=False)

# %% [markdown]
# # **Autogluon training MAE**

# %%
# Setting up
eval_metric = 'mae'
label = 'price'
problem_type='regression'
hours = 8

# Models to exclude
excluded_model_types = ['KNN']

# Initialize the TabularPredictor
predictor = TabularPredictor(label=label, eval_metric=eval_metric, problem_type=problem_type,
                             path = os.path.join(base_path, "Autogluon/202409_MAE_train"))

# Fit the model
predictor.fit(
        train_data=train,
        time_limit=3600*hours,
        presets="best_quality",
        hyperparameters={
            'GBM': ['GBMLarge'],
            'CAT': {},
            'XT': {},
            'FASTAI': {},
            'FT_TRANSFORMER': {}
        },
        hyperparameter_tune_kwargs="auto",
        num_bag_folds=8,
        num_bag_sets=20,
        num_stack_levels=2,
        ag_args_ensemble={'use_orig_features': True},
        full_weighted_ensemble_additionally=True,
        feature_prune_kwargs={}
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="/kaggle/working/Autogluon/202409_MAE_train"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          8
# Memory Avail:       48.66 GB / 50.99 GB (95.4%)
# Disk Space Avail:   179.92 GB / 225.83 GB (79.7%)
# ===================================================
# Presets specified: ['best_quality']
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=2, num_bag_folds=8, num_bag_sets=20
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 7200s of the 28800s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-09-29 15:53:36,005	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "/kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho"
# (_dystack pid=8021) Running DyStack sub-fit ...
# (_dystack pid=8021) Beginning AutoGluon training ... Time limit = 7197s
# (_dystack pid=8021) AutoGluon will save models to "/kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho"
# (_dystack pid=8021) Train Data Rows:    171148
# (_dystack pid=8021) Train Data Columns: 16
# (_dystack pid=8021) Label Column:       price
# (_dystack pid=8021) Problem Type:       regression
# (_dystack pid=8021) Preprocessing data ...
# (_dystack pid=8021) Using Feature Generators to preprocess the data ...
# (_dystack pid=8021) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=8021) 	Available Memory:                    49326.00 MB
# (_dystack pid=8021) 	Train Data (Original)  Memory Usage: 11.02 MB (0.0% of available memory)
# (_dystack pid=8021) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=8021) 	Stage 1 Generators:
# (_dystack pid=8021) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=8021) 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=8021) 	Stage 2 Generators:
# (_dystack pid=8021) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=8021) 	Stage 3 Generators:
# (_dystack pid=8021) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=8021) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=8021) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=8021) 	Stage 4 Generators:
# (_dystack pid=8021) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=8021) 	Stage 5 Generators:
# (_dystack pid=8021) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=8021) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=8021) 		('category', []) : 9 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# (_dystack pid=8021) 		('float', [])    : 3 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age']
# (_dystack pid=8021) 		('int', [])      : 4 | ['model_year', 'milage', 'Vehicle_Age', 'Is_Luxury_Brand']
# (_dystack pid=8021) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=8021) 		('category', [])  : 8 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# (_dystack pid=8021) 		('float', [])     : 3 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age']
# (_dystack pid=8021) 		('int', [])       : 3 | ['model_year', 'milage', 'Vehicle_Age']
# (_dystack pid=8021) 		('int', ['bool']) : 2 | ['clean_title', 'Is_Luxury_Brand']
# (_dystack pid=8021) 	0.2s = Fit runtime
# (_dystack pid=8021) 	16 features in original data used to generate 16 features in processed data.
# (_dystack pid=8021) 	Train Data (Processed) Memory Usage: 9.80 MB (0.0% of available memory)
# (_dystack pid=8021) Data preprocessing and feature engineering runtime = 0.27s ...
# (_dystack pid=8021) AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# (_dystack pid=8021) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=8021) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=8021) User-specified model hyperparameters to be fit:
# (_dystack pid=8021) {
# (_dystack pid=8021) 	'GBM': ['GBMLarge'],
# (_dystack pid=8021) 	'CAT': {},
# (_dystack pid=8021) 	'XT': {},
# (_dystack pid=8021) 	'FASTAI': {},
# (_dystack pid=8021) 	'FT_TRANSFORMER': {},
# (_dystack pid=8021) }
# (_dystack pid=8021) AutoGluon will fit 3 stack levels (L1 to L3) ...
# (_dystack pid=8021) Fitting 5 L1 models ...
# (_dystack pid=8021) Hyperparameter tuning model: CatBoost_BAG_L1 ... Tuning model for up to 575.56s of the 7196.35s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=8021) 	Stopping HPO to satisfy time limit...
# (_dystack pid=8021) Fitted model: CatBoost_BAG_L1/T1 ...
# (_dystack pid=8021) 	-19650.2315	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	375.02s	 = Training   runtime
# (_dystack pid=8021) 	0.47s	 = Validation runtime
# (_dystack pid=8021) Hyperparameter tuning model: ExtraTrees_BAG_L1 ... Tuning model for up to 575.56s of the 6819.93s of remaining time.
# (_dystack pid=8021) 	No hyperparameter search space specified for ExtraTrees_BAG_L1. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=8021) Fitted model: ExtraTrees_BAG_L1 ...
# (_dystack pid=8021) 	-21671.129	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	28.99s	 = Training   runtime
# (_dystack pid=8021) 	4.94s	 = Validation runtime
# (_dystack pid=8021) Hyperparameter tuning model: NeuralNetFastAI_BAG_L1 ... Tuning model for up to 575.56s of the 6790.86s of remaining time.
# (_dystack pid=8021) [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (_dystack pid=8021) ╭───────────────────────────────────────────────────────────╮
# (_dystack pid=8021) │ Configuration for experiment     NeuralNetFastAI_BAG_L1   │
# (_dystack pid=8021) ├───────────────────────────────────────────────────────────┤
# (_dystack pid=8021) │ Search algorithm                 SearchGenerator          │
# (_dystack pid=8021) │ Scheduler                        FIFOScheduler            │
# (_dystack pid=8021) │ Number of trials                 1000                     │
# (_dystack pid=8021) ╰───────────────────────────────────────────────────────────╯
# (_dystack pid=8021)
# (_dystack pid=8021) View detailed results here: /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1
# (_dystack pid=8021)
# (_dystack pid=8021) Reached timeout of 575.5639956877899 seconds. Stopping all trials.
# (_dystack pid=8021) Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# (_dystack pid=8021) You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# (_dystack pid=8021) You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# (_dystack pid=8021) Wrote the latest version of all result files and experiment state to '/kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1' in 0.0095s.
# (_dystack pid=8021) Failed to fetch metrics for 7 trial(s):
# (_dystack pid=8021) - a1dd3be3: FileNotFoundError('Could not fetch metrics for a1dd3be3: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/a1dd3be3')
# (_dystack pid=8021) - 03cfc4e0: FileNotFoundError('Could not fetch metrics for 03cfc4e0: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/03cfc4e0')
# (_dystack pid=8021) - 89db7ee8: FileNotFoundError('Could not fetch metrics for 89db7ee8: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/89db7ee8')
# (_dystack pid=8021) - 56940184: FileNotFoundError('Could not fetch metrics for 56940184: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/56940184')
# (_dystack pid=8021) - 4b11201d: FileNotFoundError('Could not fetch metrics for 4b11201d: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/4b11201d')
# (_dystack pid=8021) - 1c4efdd2: FileNotFoundError('Could not fetch metrics for 1c4efdd2: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/1c4efdd2')
# (_dystack pid=8021) - 85647110: FileNotFoundError('Could not fetch metrics for 85647110: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/85647110')
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L1/a1dd3be3 ...
# (_dystack pid=8021) 	-19266.3722	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	319.58s	 = Training   runtime
# (_dystack pid=8021) 	3.92s	 = Validation runtime
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L1/03cfc4e0 ...
# (_dystack pid=8021) 	-19045.1637	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	128.03s	 = Training   runtime
# (_dystack pid=8021) 	2.73s	 = Validation runtime
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L1/89db7ee8 ...
# (_dystack pid=8021) 	-19457.2571	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	69.27s	 = Training   runtime
# (_dystack pid=8021) 	2.02s	 = Validation runtime
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L1/56940184 ...
# (_dystack pid=8021) 	-19123.1047	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	37.68s	 = Training   runtime
# (_dystack pid=8021) 	1.47s	 = Validation runtime
# (_dystack pid=8021) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 575.56s of the 6214.61s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.17%)
# (_dystack pid=8021) 	-19758.5914	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	7.34s	 = Training   runtime
# (_dystack pid=8021) 	2.13s	 = Validation runtime
# (_dystack pid=8021) Hyperparameter tuning model: FTTransformer_BAG_L1 ... Tuning model for up to 575.56s of the 6204.27s of remaining time.
# (_dystack pid=8021) 	No hyperparameter search space specified for FTTransformer_BAG_L1. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=8021) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_dystack pid=8021) Warning: Exception caused FTTransformer_BAG_L1 to fail during hyperparameter tuning... Skipping this model.
# (_dystack pid=8021) Traceback (most recent call last):
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 1333, in _hyperparameter_tune
# (_dystack pid=8021)     hpo_executor.validate_search_space(search_space, self.name)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/hpo/executors.py", line 512, in validate_search_space
# (_dystack pid=8021)     raise EmptySearchSpace
# (_dystack pid=8021) autogluon.core.hpo.exceptions.EmptySearchSpace
# (_dystack pid=8021)
# (_dystack pid=8021) During handling of the above exception, another exception occurred:
# (_dystack pid=8021)
# (_dystack pid=8021) Traceback (most recent call last):
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 2221, in _train_single_full
# (_dystack pid=8021)     hpo_models, hpo_results = model.hyperparameter_tune(
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 1501, in hyperparameter_tune
# (_dystack pid=8021)     return self._hyperparameter_tune(hpo_executor=hpo_executor, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 184, in _hyperparameter_tune
# (_dystack pid=8021)     return super()._hyperparameter_tune(X=X, y=y, k_fold=k_fold, hpo_executor=hpo_executor, preprocess_kwargs=preprocess_kwargs, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 1335, in _hyperparameter_tune
# (_dystack pid=8021)     return skip_hpo(X=X, y=y, X_val=X_val, y_val=y_val, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/model_trial.py", line 122, in skip_hpo
# (_dystack pid=8021)     fit_and_save_model(model=model, fit_args=fit_model_args, predict_proba_args=predict_proba_args, y_val=y_val, time_start=time.time(), time_limit=time_limit)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/model_trial.py", line 96, in fit_and_save_model
# (_dystack pid=8021)     model.fit(**fit_args, time_limit=time_left)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=8021)     out = self._fit(**kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
# (_dystack pid=8021)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 288, in _fit
# (_dystack pid=8021)     self._fit_folds(
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 714, in _fit_folds
# (_dystack pid=8021)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
# (_dystack pid=8021)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 610, in _run_parallel
# (_dystack pid=8021)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 572, in _process_fold_results
# (_dystack pid=8021)     raise processed_exception
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 537, in _process_fold_results
# (_dystack pid=8021)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=8021)     return fn(*args, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
# (_dystack pid=8021)     return func(*args, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2667, in get
# (_dystack pid=8021)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 864, in get_objects
# (_dystack pid=8021)     raise value.as_instanceof_cause()
# (_dystack pid=8021) ray.exceptions.RayTaskError(ImportError): ray::_ray_fit() (pid=15800, ip=172.28.0.12)
# (_dystack pid=8021) ModuleNotFoundError: No module named 'autogluon.multimodal'
# (_dystack pid=8021)
# (_dystack pid=8021) During handling of the above exception, another exception occurred:
# (_dystack pid=8021)
# (_dystack pid=8021) ray::_ray_fit() (pid=15800, ip=172.28.0.12)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=8021)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=8021)     out = self._fit(**kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/automm/ft_transformer.py", line 53, in _fit
# (_dystack pid=8021)     super()._fit(X, num_gpus=num_gpus, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/automm/automm_model.py", line 141, in _fit
# (_dystack pid=8021)     try_import_autogluon_multimodal()
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/common/utils/try_import.py", line 140, in try_import_autogluon_multimodal
# (_dystack pid=8021)     raise ImportError("`import autogluon.multimodal` failed.\n" f"A quick tip is to install via `pip install autogluon.multimodal=={__version__}`.\n")
# (_dystack pid=8021) ImportError: `import autogluon.multimodal` failed.
# (_dystack pid=8021) A quick tip is to install via `pip install autogluon.multimodal==1.1.1`.
# (_dystack pid=8021) ray::_ray_fit() (pid=15800, ip=172.28.0.12)
# (_dystack pid=8021) ModuleNotFoundError: No module named 'autogluon.multimodal'
# (_dystack pid=8021)
# (_dystack pid=8021) During handling of the above exception, another exception occurred:
# (_dystack pid=8021)
# (_dystack pid=8021) ray::_ray_fit() (pid=15800, ip=172.28.0.12)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=8021)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=8021)     out = self._fit(**kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/automm/ft_transformer.py", line 53, in _fit
# (_dystack pid=8021)     super()._fit(X, num_gpus=num_gpus, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/automm/automm_model.py", line 141, in _fit
# (_dystack pid=8021)     try_import_autogluon_multimodal()
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/common/utils/try_import.py", line 140, in try_import_autogluon_multimodal
# (_dystack pid=8021)     raise ImportError("`import autogluon.multimodal` failed.\n" f"A quick tip is to install via `pip install autogluon.multimodal=={__version__}`.\n")
# (_dystack pid=8021) ImportError: `import autogluon.multimodal` failed.
# (_dystack pid=8021) A quick tip is to install via `pip install autogluon.multimodal==1.1.1`.
# (_dystack pid=8021) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=15798, ip=172.28.0.12)
# (_dystack pid=8021) ModuleNotFoundError: No module named 'autogluon.multimodal'
# (_dystack pid=8021)
# (_dystack pid=8021) During handling of the above exception, another exception occurred:
# (_dystack pid=8021)
# (_dystack pid=8021) ray::_ray_fit() (pid=15798, ip=172.28.0.12)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=8021)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=8021)     out = self._fit(**kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/automm/ft_transformer.py", line 53, in _fit
# (_dystack pid=8021)     super()._fit(X, num_gpus=num_gpus, **kwargs)
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/automm/automm_model.py", line 141, in _fit
# (_dystack pid=8021)     try_import_autogluon_multimodal()
# (_dystack pid=8021)   File "/usr/local/lib/python3.10/dist-packages/autogluon/common/utils/try_import.py", line 140, in try_import_autogluon_multimodal
# (_dystack pid=8021)     raise ImportError("`import autogluon.multimodal` failed.\n" f"A quick tip is to install via `pip install autogluon.multimodal=={__version__}`.\n")
# (_dystack pid=8021) ImportError: `import autogluon.multimodal` failed.
# (_dystack pid=8021) A quick tip is to install via `pip install autogluon.multimodal==1.1.1`.
# (_dystack pid=8021) Performing feature pruning with model: FeatureSelector_LightGBMLarge_BAG_L1, total time limit: 1208.9s, stop threshold: 10, prune ratio: 0.05, prune threshold: noise.
# (_dystack pid=8021) 	Number of training samples 171148 is greater than 50000. Using 50000 samples as training data.
# (_dystack pid=8021) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_ray_fit pid=15798) WARNING: Training S1F3 on CPU (no GPU specified). This could take a long time. Use GPU to speed up training.
# (_dystack pid=8021) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=8021) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=8021) 	Feature selection model is bagged and replace_bag=True. Using a non-bagged version of the model for feature selection.
# (_dystack pid=8021) 	Expected model fit time: 3.06s, and expected candidate generation time: 1.91s.
# (_dystack pid=8021) 	Round 1 of feature pruning model fit (3.06s):
# (_dystack pid=8021) 		Validation score of the model fit on original features is (-20317.0364).
# (_dystack pid=8021) 	Round 2 of feature pruning model fit (3.63s):
# (_dystack pid=8021) 		Validation score of the current model fit on 15 features (-20327.6588) is not better than validation score of the best model fit on 16 features (-20317.0364). Retrying.
# (_ray_fit pid=15800) WARNING: Training S1F5 on CPU (no GPU specified). This could take a long time. Use GPU to speed up training.
# (_dystack pid=8021) 	Round 3 of feature pruning model fit (1.98s):
# (_dystack pid=8021) 		Validation score of the current model fit on 15 features (-20327.6588) is not better than validation score of the best model fit on 16 features (-20317.0364). Retrying.
# (_dystack pid=8021) 	Round 4 of feature pruning model fit (2.07s):
# (_dystack pid=8021) 		Validation score of the current model fit on 15 features (-20327.6588) is not better than validation score of the best model fit on 16 features (-20317.0364). Retrying.
# (_dystack pid=8021) 	Round 5 of feature pruning model fit (3.83s):
# (_dystack pid=8021) 		Validation score of the current model fit on 15 features (-20308.655) is better than validation score of the best model fit on 16 features (-20317.0364). Updating model.
# (_dystack pid=8021) 	Round 6 of feature pruning model fit (1.92s):
# (_dystack pid=8021) 		Validation score of the current model fit on 14 features (-20418.1141) is not better than validation score of the best model fit on 15 features (-20308.655). Retrying.
# (_dystack pid=8021) 	Round 7 of feature pruning model fit (2.07s):
# (_dystack pid=8021) 		Validation score of the current model fit on 14 features (-20418.1141) is not better than validation score of the best model fit on 15 features (-20308.655). Retrying.
# (_dystack pid=8021) 	Round 8 of feature pruning model fit (1.84s):
# (_dystack pid=8021) 		Validation score of the current model fit on 14 features (-20342.9126) is not better than validation score of the best model fit on 15 features (-20308.655). Retrying.
# (_dystack pid=8021) 	Round 9 of feature pruning model fit (3.03s):
# (_dystack pid=8021) 		Validation score of the current model fit on 14 features (-20357.1868) is not better than validation score of the best model fit on 15 features (-20308.655). Retrying.
# (_dystack pid=8021) 	Round 10 of feature pruning model fit (2.0s):
# (_dystack pid=8021) 		Validation score of the current model fit on 14 features (-20418.1141) is not better than validation score of the best model fit on 15 features (-20308.655). Retrying.
# (_dystack pid=8021) 	Round 11 of feature pruning model fit (1.93s):
# (_dystack pid=8021) 		Validation score of the current model fit on 14 features (-20418.1141) is not better than validation score of the best model fit on 15 features (-20308.655). Retrying.
# (_dystack pid=8021) 	Time is up while computing feature importance or there are no more features to prune. Ending...
# (_dystack pid=8021) 	Successfully ended prune loop after 12 feature pruning rounds (45.71s).
# (_dystack pid=8021) 	Feature count before/after feature pruning: 16 -> 15.
# (_dystack pid=8021) Fitting model: CatBoost_BAG_L1/T1_Prune ... Training model for up to 2157.52s of the 6156.29s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.16%)
# (_dystack pid=8021) 	-19649.4183	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	343.14s	 = Training   runtime
# (_dystack pid=8021) 	0.59s	 = Validation runtime
# (_dystack pid=8021) Fitting model: ExtraTrees_BAG_L1_Prune ... Training model for up to 1811.88s of the 5810.65s of remaining time.
# (_dystack pid=8021) 	-21680.8334	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	20.0s	 = Training   runtime
# (_dystack pid=8021) 	4.99s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L1/a1dd3be3_Prune ... Training model for up to 1785.93s of the 5784.7s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# (_dystack pid=8021) 	-19178.1454	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	326.85s	 = Training   runtime
# (_dystack pid=8021) 	3.83s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L1/03cfc4e0_Prune ... Training model for up to 1456.43s of the 5455.19s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.25%)
# (_dystack pid=8021) 	-18923.315	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	110.15s	 = Training   runtime
# (_dystack pid=8021) 	2.73s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L1/89db7ee8_Prune ... Training model for up to 1343.53s of the 5342.3s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# (_dystack pid=8021) 	-19387.343	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	64.55s	 = Training   runtime
# (_dystack pid=8021) 	2.28s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L1/56940184_Prune ... Training model for up to 1276.0s of the 5274.77s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# (_dystack pid=8021) 	-18840.2133	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	91.23s	 = Training   runtime
# (_dystack pid=8021) 	1.37s	 = Validation runtime
# (_dystack pid=8021) Fitting model: LightGBMLarge_BAG_L1_Prune ... Training model for up to 1181.65s of the 5180.42s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_dystack pid=8021) 	-19782.7757	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	6.37s	 = Training   runtime
# (_dystack pid=8021) 	2.04s	 = Validation runtime
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-19649.4183 vs -19650.2315). Replacing original model...
# (_dystack pid=8021) Deleting model CatBoost_BAG_L1/T1. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/CatBoost_BAG_L1/T1 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is not better than original model's score (-21680.8334 vs -21671.129). Keeping original model...
# (_dystack pid=8021) Deleting model ExtraTrees_BAG_L1_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/ExtraTrees_BAG_L1_Prune will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-19178.1454 vs -19266.3722). Replacing original model...
# (_dystack pid=8021) Deleting model NeuralNetFastAI_BAG_L1/a1dd3be3. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/a1dd3be3 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-18923.315 vs -19045.1637). Replacing original model...
# (_dystack pid=8021) Deleting model NeuralNetFastAI_BAG_L1/03cfc4e0. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/03cfc4e0 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-19387.343 vs -19457.2571). Replacing original model...
# (_dystack pid=8021) Deleting model NeuralNetFastAI_BAG_L1/89db7ee8. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/89db7ee8 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-18840.2133 vs -19123.1047). Replacing original model...
# (_dystack pid=8021) Deleting model NeuralNetFastAI_BAG_L1/56940184. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/56940184 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is not better than original model's score (-19782.7757 vs -19758.5914). Keeping original model...
# (_dystack pid=8021) Deleting model LightGBMLarge_BAG_L1_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/LightGBMLarge_BAG_L1_Prune will be removed.
# (_dystack pid=8021) Completed 1/20 k-fold bagging repeats ...
# (_dystack pid=8021) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 5170.57s of remaining time.
# (_dystack pid=8021) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1/03cfc4e0_Prune': 0.375, 'NeuralNetFastAI_BAG_L1/56940184_Prune': 0.333, 'NeuralNetFastAI_BAG_L1/a1dd3be3_Prune': 0.208, 'CatBoost_BAG_L1/T1_Prune': 0.083}
# (_dystack pid=8021) 	-18504.8893	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	0.32s	 = Training   runtime
# (_dystack pid=8021) 	0.0s	 = Validation runtime
# (_dystack pid=8021) Fitting 4 L2 models ...
# (_dystack pid=8021) Hyperparameter tuning model: CatBoost_BAG_L2 ... Tuning model for up to 775.34s of the 5170.21s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.28%)
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=8021) 	Stopping HPO to satisfy time limit...
# (_dystack pid=8021) Fitted model: CatBoost_BAG_L2/T1 ...
# (_dystack pid=8021) 	-19188.2731	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	75.14s	 = Training   runtime
# (_dystack pid=8021) 	0.28s	 = Validation runtime
# (_dystack pid=8021) Fitted model: CatBoost_BAG_L2/T2 ...
# (_dystack pid=8021) 	-19217.1374	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	41.36s	 = Training   runtime
# (_dystack pid=8021) 	0.19s	 = Validation runtime
# (_dystack pid=8021) Fitted model: CatBoost_BAG_L2/T3 ...
# (_dystack pid=8021) 	-19168.8062	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	295.98s	 = Training   runtime
# (_dystack pid=8021) 	0.46s	 = Validation runtime
# (_dystack pid=8021) Fitted model: CatBoost_BAG_L2/T4 ...
# (_dystack pid=8021) 	-19172.3323	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	206.61s	 = Training   runtime
# (_dystack pid=8021) 	0.38s	 = Validation runtime
# (_dystack pid=8021) Fitted model: CatBoost_BAG_L2/T5 ...
# (_dystack pid=8021) 	-19169.8776	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	123.13s	 = Training   runtime
# (_dystack pid=8021) 	0.37s	 = Validation runtime
# (_dystack pid=8021) Hyperparameter tuning model: ExtraTrees_BAG_L2 ... Tuning model for up to 775.34s of the 4427.71s of remaining time.
# (_dystack pid=8021) 	No hyperparameter search space specified for ExtraTrees_BAG_L2. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=8021) Fitted model: ExtraTrees_BAG_L2 ...
# (_dystack pid=8021) 	-21257.7222	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	46.76s	 = Training   runtime
# (_dystack pid=8021) 	5.55s	 = Validation runtime
# (_dystack pid=8021) Hyperparameter tuning model: NeuralNetFastAI_BAG_L2 ... Tuning model for up to 775.34s of the 4380.84s of remaining time.
# (_dystack pid=8021) ╭───────────────────────────────────────────────────────────╮
# (_dystack pid=8021) │ Configuration for experiment     NeuralNetFastAI_BAG_L2   │
# (_dystack pid=8021) ├───────────────────────────────────────────────────────────┤
# (_dystack pid=8021) │ Search algorithm                 SearchGenerator          │
# (_dystack pid=8021) │ Scheduler                        FIFOScheduler            │
# (_dystack pid=8021) │ Number of trials                 1000                     │
# (_dystack pid=8021) ╰───────────────────────────────────────────────────────────╯
# (_dystack pid=8021)
# (_dystack pid=8021) View detailed results here: /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2
# (_dystack pid=8021) [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (_dystack pid=8021) Reached timeout of 775.3406988262295 seconds. Stopping all trials.
# (_dystack pid=8021) Wrote the latest version of all result files and experiment state to '/kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2' in 0.0322s.
# (_dystack pid=8021)
# (_dystack pid=8021) Failed to fetch metrics for 6 trial(s):
# (_dystack pid=8021) - da69b124: FileNotFoundError('Could not fetch metrics for da69b124: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/da69b124')
# (_dystack pid=8021) - 30f8e5a4: FileNotFoundError('Could not fetch metrics for 30f8e5a4: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/30f8e5a4')
# (_dystack pid=8021) - 7aee4d6a: FileNotFoundError('Could not fetch metrics for 7aee4d6a: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/7aee4d6a')
# (_dystack pid=8021) - 6e1f4d4e: FileNotFoundError('Could not fetch metrics for 6e1f4d4e: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/6e1f4d4e')
# (_dystack pid=8021) - 843c3d8c: FileNotFoundError('Could not fetch metrics for 843c3d8c: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/843c3d8c')
# (_dystack pid=8021) - 94027b35: FileNotFoundError('Could not fetch metrics for 94027b35: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/94027b35')
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L2/da69b124 ...
# (_dystack pid=8021) 	-18632.6575	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	323.94s	 = Training   runtime
# (_dystack pid=8021) 	4.09s	 = Validation runtime
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L2/30f8e5a4 ...
# (_dystack pid=8021) 	-18812.6013	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	93.01s	 = Training   runtime
# (_dystack pid=8021) 	4.17s	 = Validation runtime
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L2/7aee4d6a ...
# (_dystack pid=8021) 	-18823.8344	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	206.0s	 = Training   runtime
# (_dystack pid=8021) 	7.28s	 = Validation runtime
# (_dystack pid=8021) Fitted model: NeuralNetFastAI_BAG_L2/6e1f4d4e ...
# (_dystack pid=8021) 	-18874.5448	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	108.4s	 = Training   runtime
# (_dystack pid=8021) 	4.39s	 = Validation runtime
# (_dystack pid=8021) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 775.34s of the 3595.09s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=8021) 	-19869.3369	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	7.49s	 = Training   runtime
# (_dystack pid=8021) 	1.32s	 = Validation runtime
# (_dystack pid=8021) Performing feature pruning with model: FeatureSelector_LightGBMLarge_BAG_L2, total time limit: 272.76s, stop threshold: 10, prune ratio: 0.05, prune threshold: noise.
# (_dystack pid=8021) 	Number of training samples 171148 is greater than 50000. Using 50000 samples as training data.
# (_dystack pid=8021) 	Feature selection model is bagged and replace_bag=True. Using a non-bagged version of the model for feature selection.
# (_dystack pid=8021) 	Expected model fit time: 2.74s, and expected candidate generation time: 1.81s.
# (_dystack pid=8021) 	Round 1 of feature pruning model fit (2.74s):
# (_dystack pid=8021) 		Validation score of the model fit on original features is (-20364.5818).
# (_dystack pid=8021) 	Round 2 of feature pruning model fit (1.93s):
# (_dystack pid=8021) 		Validation score of the current model fit on 22 features (-20362.4575) is better than validation score of the best model fit on 23 features (-20364.5818). Updating model.
# (_dystack pid=8021) 	Time is up while computing feature importance or there are no more features to prune. Ending...
# (_dystack pid=8021) 	Successfully ended prune loop after 3 feature pruning rounds (7.84s).
# (_dystack pid=8021) 	Feature count before/after feature pruning: 23 -> 22.
# (_dystack pid=8021) Fitting model: CatBoost_BAG_L2/T1_Prune ... Training model for up to 1851.51s of the 3575.76s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=8021) 	-19184.6619	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	68.5s	 = Training   runtime
# (_dystack pid=8021) 	0.22s	 = Validation runtime
# (_dystack pid=8021) Fitting model: CatBoost_BAG_L2/T2_Prune ... Training model for up to 1780.67s of the 3504.91s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# (_dystack pid=8021) 	-19231.2134	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	28.53s	 = Training   runtime
# (_dystack pid=8021) 	0.18s	 = Validation runtime
# (_dystack pid=8021) Fitting model: CatBoost_BAG_L2/T3_Prune ... Training model for up to 1748.95s of the 3473.19s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.27%)
# (_dystack pid=8021) 	-19158.3132	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	189.91s	 = Training   runtime
# (_dystack pid=8021) 	0.34s	 = Validation runtime
# (_dystack pid=8021) Fitting model: CatBoost_BAG_L2/T4_Prune ... Training model for up to 1556.43s of the 3280.67s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# (_dystack pid=8021) 	-19166.0738	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	188.84s	 = Training   runtime
# (_dystack pid=8021) 	0.4s	 = Validation runtime
# (_dystack pid=8021) Fitting model: CatBoost_BAG_L2/T5_Prune ... Training model for up to 1365.16s of the 3089.41s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# (_dystack pid=8021) 	-19169.7217	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	119.72s	 = Training   runtime
# (_dystack pid=8021) 	0.29s	 = Validation runtime
# (_dystack pid=8021) Fitting model: ExtraTrees_BAG_L2_Prune ... Training model for up to 1243.05s of the 2967.3s of remaining time.
# (_dystack pid=8021) 	-21196.5714	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	34.15s	 = Training   runtime
# (_dystack pid=8021) 	5.33s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L2/da69b124_Prune ... Training model for up to 1202.58s of the 2926.82s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_dystack pid=8021) 	-18585.111	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	319.23s	 = Training   runtime
# (_dystack pid=8021) 	3.98s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L2/30f8e5a4_Prune ... Training model for up to 880.62s of the 2604.86s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_dystack pid=8021) 	-18848.6373	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	85.51s	 = Training   runtime
# (_dystack pid=8021) 	4.19s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L2/7aee4d6a_Prune ... Training model for up to 792.45s of the 2516.7s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_dystack pid=8021) 	-18952.3124	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	188.66s	 = Training   runtime
# (_dystack pid=8021) 	6.42s	 = Validation runtime
# (_dystack pid=8021) Fitting model: NeuralNetFastAI_BAG_L2/6e1f4d4e_Prune ... Training model for up to 600.47s of the 2324.72s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_dystack pid=8021) 	-18934.9447	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	100.96s	 = Training   runtime
# (_dystack pid=8021) 	4.35s	 = Validation runtime
# (_dystack pid=8021) Fitting model: LightGBMLarge_BAG_L2_Prune ... Training model for up to 496.56s of the 2220.8s of remaining time.
# (_dystack pid=8021) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=8021) 	-19877.0861	 = Validation score   (-mean_absolute_error)
# (_dystack pid=8021) 	7.07s	 = Training   runtime
# (_dystack pid=8021) 	1.43s	 = Validation runtime
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-19184.6619 vs -19188.2731). Replacing original model...
# (_dystack pid=8021) Deleting model CatBoost_BAG_L2/T1. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/CatBoost_BAG_L2/T1 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is not better than original model's score (-19231.2134 vs -19217.1374). Keeping original model...
# (_dystack pid=8021) Deleting model CatBoost_BAG_L2/T2_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/CatBoost_BAG_L2/CatBoost_BAG_L2/T2_Prune will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-19158.3132 vs -19168.8062). Replacing original model...
# (_dystack pid=8021) Deleting model CatBoost_BAG_L2/T3. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/CatBoost_BAG_L2/T3 will be removed.
# (_dystack pid=8021) Model trained with feature pruning score is better than original model's score (-19166.0738 vs -19172.3323). Replacing original model...
# (_dystack pid=8021) Deleting model CatBoost_BAG_L2/T4. All files under /kaggle/working/Autogluon/202409_MAE_train/ds_sub_fit/sub_fit_ho/models/CatBoost_BAG_L2/T4 will be removed.
# ...
# Deleting model CatBoost_BAG_L2/T5. All files under /kaggle/working/Autogluon/202409_MAE_train/models/CatBoost_BAG_L2/T5 will be removed.
# Model trained with feature pruning score is better than original model's score (-19080.3148 vs -19082.5742). Replacing original model...
# Deleting model CatBoost_BAG_L2/T6. All files under /kaggle/working/Autogluon/202409_MAE_train/models/CatBoost_BAG_L2/T6 will be removed.
# Model trained with feature pruning score is not better than original model's score (-19076.1794 vs -19074.1442). Keeping original model...
# Deleting model CatBoost_BAG_L2/T7_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/models/CatBoost_BAG_L2/CatBoost_BAG_L2/T7_Prune will be removed.
# Model trained with feature pruning score is better than original model's score (-19080.0867 vs -19080.7854). Replacing original model...
# Deleting model CatBoost_BAG_L2/T8. All files under /kaggle/working/Autogluon/202409_MAE_train/models/CatBoost_BAG_L2/T8 will be removed.
# Model trained with feature pruning score is better than original model's score (-21174.1717 vs -21196.5502). Replacing original model...
# Deleting model ExtraTrees_BAG_L2. All files under /kaggle/working/Autogluon/202409_MAE_train/models/ExtraTrees_BAG_L2 will be removed.
# Model trained with feature pruning score is better than original model's score (-18652.6265 vs -18699.9531). Replacing original model...
# Deleting model NeuralNetFastAI_BAG_L2/519986ed. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/519986ed will be removed.
# Model trained with feature pruning score is better than original model's score (-19202.3021 vs -19212.0833). Replacing original model...
# Deleting model NeuralNetFastAI_BAG_L2/9bafefd8. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/9bafefd8 will be removed.
# Model trained with feature pruning score is not better than original model's score (-18763.7495 vs -18723.5091). Keeping original model...
# Deleting model NeuralNetFastAI_BAG_L2/750e34cd_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/NeuralNetFastAI_BAG_L2/750e34cd_Prune will be removed.
# Model trained with feature pruning score is not better than original model's score (-18534.9494 vs -18433.1149). Keeping original model...
# Deleting model NeuralNetFastAI_BAG_L2/b293ca8b_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/NeuralNetFastAI_BAG_L2/b293ca8b_Prune will be removed.
# Model trained with feature pruning score is better than original model's score (-19133.1776 vs -19259.9463). Replacing original model...
# Deleting model NeuralNetFastAI_BAG_L2/e17f26ee. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/e17f26ee will be removed.
# Model trained with feature pruning score is better than original model's score (-18508.8352 vs -18711.4387). Replacing original model...
# Deleting model NeuralNetFastAI_BAG_L2/dcee2eb7. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/dcee2eb7 will be removed.
# Model trained with feature pruning score is not better than original model's score (-18528.1801 vs -18480.1807). Keeping original model...
# Deleting model NeuralNetFastAI_BAG_L2/238d0081_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/NeuralNetFastAI_BAG_L2/238d0081_Prune will be removed.
# Model trained with feature pruning score is better than original model's score (-18783.6699 vs -19084.1429). Replacing original model...
# Deleting model NeuralNetFastAI_BAG_L2/6d5d6101. All files under /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L2/6d5d6101 will be removed.
# Model trained with feature pruning score is not better than original model's score (-19733.6693 vs -19726.5627). Keeping original model...
# Deleting model LightGBMLarge_BAG_L2_Prune. All files under /kaggle/working/Autogluon/202409_MAE_train/models/LightGBMLarge_BAG_L2_Prune will be removed.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 992.25s of the 6169.12s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2/b293ca8b': 0.32, 'NeuralNetFastAI_BAG_L2/238d0081': 0.32, 'NeuralNetFastAI_BAG_L2/dcee2eb7_Prune': 0.24, 'NeuralNetFastAI_BAG_L2/519986ed_Prune': 0.12}
# 	-18206.1968	 = Validation score   (-mean_absolute_error)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 4 L3 models ...
# Hyperparameter tuning model: CatBoost_BAG_L3 ... Tuning model for up to 1387.95s of the 6168.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	Stopping HPO to satisfy time limit...
# Fitted model: CatBoost_BAG_L3/T1 ...
# 	-19084.6276	 = Validation score   (-mean_absolute_error)
# 	77.12s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T2 ...
# 	-19103.6592	 = Validation score   (-mean_absolute_error)
# 	32.45s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T3 ...
# 	-19072.6132	 = Validation score   (-mean_absolute_error)
# 	170.34s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T4 ...
# 	-19077.2569	 = Validation score   (-mean_absolute_error)
# 	210.05s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T5 ...
# 	-19077.1272	 = Validation score   (-mean_absolute_error)
# 	128.97s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T6 ...
# 	-19078.2052	 = Validation score   (-mean_absolute_error)
# 	127.8s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T7 ...
# 	-19070.3928	 = Validation score   (-mean_absolute_error)
# 	438.96s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitted model: CatBoost_BAG_L3/T8 ...
# 	-19076.1843	 = Validation score   (-mean_absolute_error)
# 	160.42s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Hyperparameter tuning model: ExtraTrees_BAG_L3 ... Tuning model for up to 1387.95s of the 4821.96s of remaining time.
# 	No hyperparameter search space specified for ExtraTrees_BAG_L3. Skipping HPO. Will train one model based on the provided hyperparameters.
# Fitted model: ExtraTrees_BAG_L3 ...
# 	-21304.0909	 = Validation score   (-mean_absolute_error)
# 	74.71s	 = Training   runtime
# 	7.22s	 = Validation runtime
# Hyperparameter tuning model: NeuralNetFastAI_BAG_L3 ... Tuning model for up to 1387.95s of the 4746.94s of remaining time.
# 2024-09-29 22:34:26,883	INFO tune.py:622 -- [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# +-----------------------------------------------------------+
# | Configuration for experiment     NeuralNetFastAI_BAG_L3   |
# +-----------------------------------------------------------+
# | Search algorithm                 SearchGenerator          |
# | Scheduler                        FIFOScheduler            |
# | Number of trials                 1000                     |
# +-----------------------------------------------------------+
#
# View detailed results here: /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3
# 2024-09-29 22:57:35,063	INFO timeout.py:54 -- Reached timeout of 1387.9454704642296 seconds. Stopping all trials.
# 2024-09-29 22:57:35,079	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-09-29 22:57:35,084	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to '/kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3' in 0.0146s.
# 2024-09-29 22:57:36,418	WARNING experiment_analysis.py:190 -- Failed to fetch metrics for 10 trial(s):
# - 60de663d: FileNotFoundError('Could not fetch metrics for 60de663d: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/60de663d')
# - bf250dcd: FileNotFoundError('Could not fetch metrics for bf250dcd: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/bf250dcd')
# - 55fbc795: FileNotFoundError('Could not fetch metrics for 55fbc795: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/55fbc795')
# - dee372fc: FileNotFoundError('Could not fetch metrics for dee372fc: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/dee372fc')
# - 091b55a8: FileNotFoundError('Could not fetch metrics for 091b55a8: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/091b55a8')
# - 3e0f54ce: FileNotFoundError('Could not fetch metrics for 3e0f54ce: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/3e0f54ce')
# - 0d2d77ca: FileNotFoundError('Could not fetch metrics for 0d2d77ca: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/0d2d77ca')
# - 38987d95: FileNotFoundError('Could not fetch metrics for 38987d95: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/38987d95')
# - 2921c50d: FileNotFoundError('Could not fetch metrics for 2921c50d: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/2921c50d')
# - a311a04d: FileNotFoundError('Could not fetch metrics for a311a04d: both result.json and progress.csv were not found at /kaggle/working/Autogluon/202409_MAE_train/models/NeuralNetFastAI_BAG_L3/a311a04d')
# Fitted model: NeuralNetFastAI_BAG_L3/60de663d ...
# 	-18695.5934	 = Validation score   (-mean_absolute_error)
# 	391.23s	 = Training   runtime
# 	4.4s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/bf250dcd ...
# 	-19542.6882	 = Validation score   (-mean_absolute_error)
# 	203.05s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/55fbc795 ...
# 	-18623.5988	 = Validation score   (-mean_absolute_error)
# 	116.29s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/dee372fc ...
# 	-19046.319	 = Validation score   (-mean_absolute_error)
# 	146.01s	 = Training   runtime
# 	1.74s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/091b55a8 ...
# 	-18486.214	 = Validation score   (-mean_absolute_error)
# 	271.37s	 = Training   runtime
# 	2.69s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/3e0f54ce ...
# 	-18702.6153	 = Validation score   (-mean_absolute_error)
# 	107.11s	 = Training   runtime
# 	2.79s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/0d2d77ca ...
# 	-19539.5927	 = Validation score   (-mean_absolute_error)
# 	96.95s	 = Training   runtime
# 	8.77s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L3/38987d95 ...
# 	-20273.1322	 = Validation score   (-mean_absolute_error)
# 	19.87s	 = Training   runtime
# 	3.37s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 1387.95s of the 3356.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# 	-19811.8602	 = Validation score   (-mean_absolute_error)
# 	10.6s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Performing feature pruning with model: FeatureSelector_LightGBMLarge_BAG_L3, total time limit: 518.07s, stop threshold: 10, prune ratio: 0.05, prune threshold: noise.
# 	Number of training samples 192542 is greater than 50000. Using 50000 samples as training data.
# 	Feature selection model is bagged and replace_bag=True. Using a non-bagged version of the model for feature selection.
# 	Expected model fit time: 5.28s, and expected candidate generation time: 3.07s.
# 	Round 1 of feature pruning model fit (5.28s):
# 		Validation score of the model fit on original features is (-20623.3919).
# 	Round 2 of feature pruning model fit (2.69s):
# 		Validation score of the current model fit on 33 features (-20655.68) is not better than validation score of the best model fit on 34 features (-20623.3919). Retrying.
# 	Round 3 of feature pruning model fit (3.37s):
# 		Validation score of the current model fit on 33 features (-20637.2146) is not better than validation score of the best model fit on 34 features (-20623.3919). Retrying.
# 	Round 4 of feature pruning model fit (2.4s):
# 		Validation score of the current model fit on 33 features (-20631.0438) is not better than validation score of the best model fit on 34 features (-20623.3919). Retrying.
# 	Round 5 of feature pruning model fit (2.32s):
# 		Validation score of the current model fit on 33 features (-20633.8041) is not better than validation score of the best model fit on 34 features (-20623.3919). Retrying.
# 	Time is up while computing feature importance or there are no more features to prune. Ending...
# 	Successfully ended prune loop after 6 feature pruning rounds (30.2s).
# 	Feature count before/after feature pruning: 34 -> 34.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_ALL_L4 ... Training model for up to 616.86s of the 3312.95s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1/e0cb5511_Prune': 0.375, 'NeuralNetFastAI_BAG_L1/e213eaf9_Prune': 0.25, 'NeuralNetFastAI_BAG_L3/091b55a8': 0.208, 'NeuralNetFastAI_BAG_L2/b293ca8b': 0.125, 'NeuralNetFastAI_BAG_L2/238d0081': 0.042}
# 	-17982.3697	 = Validation score   (-mean_absolute_error)
# 	0.55s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 616.86s of the 3312.35s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L3/091b55a8': 0.455, 'NeuralNetFastAI_BAG_L3/60de663d': 0.227, 'NeuralNetFastAI_BAG_L3/55fbc795': 0.227, 'NeuralNetFastAI_BAG_L3/3e0f54ce': 0.091}
# 	-18214.1231	 = Validation score   (-mean_absolute_error)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 18445.41s ... Best model: WeightedEnsemble_ALL_L4 | Estimated inference throughput: 290.0 rows/s (24068 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/Autogluon/202409_MAE_train")

# %%
predictor = TabularPredictor.load(os.path.join(base_path, "Autogluon/202409_MAE_train"))

# %%
leaderboard_test = predictor.leaderboard()
leaderboard_test
# Out:
#                                     model     score_val          eval_metric  \
# 0                 WeightedEnsemble_ALL_L4 -17982.369702  mean_absolute_error
# 1                     WeightedEnsemble_L2 -18054.796327  mean_absolute_error
# 2   NeuralNetFastAI_BAG_L1/e0cb5511_Prune -18183.479282  mean_absolute_error
# 3                     WeightedEnsemble_L3 -18206.196820  mean_absolute_error
# 4                     WeightedEnsemble_L4 -18214.123080  mean_absolute_error
# 5         NeuralNetFastAI_BAG_L2/b293ca8b -18433.114924  mean_absolute_error
# 6   NeuralNetFastAI_BAG_L1/e213eaf9_Prune -18468.652920  mean_absolute_error
# 7         NeuralNetFastAI_BAG_L2/238d0081 -18480.180684  mean_absolute_error
# 8         NeuralNetFastAI_BAG_L3/091b55a8 -18486.213958  mean_absolute_error
# 9   NeuralNetFastAI_BAG_L2/dcee2eb7_Prune -18508.835151  mean_absolute_error
# 10  NeuralNetFastAI_BAG_L1/799f39c8_Prune -18573.409108  mean_absolute_error
# 11        NeuralNetFastAI_BAG_L3/55fbc795 -18623.598828  mean_absolute_error
# 12  NeuralNetFastAI_BAG_L2/519986ed_Prune -18652.626460  mean_absolute_error
# 13        NeuralNetFastAI_BAG_L3/60de663d -18695.593400  mean_absolute_error
# 14        NeuralNetFastAI_BAG_L3/3e0f54ce -18702.615295  mean_absolute_error
# 15        NeuralNetFastAI_BAG_L2/750e34cd -18723.509052  mean_absolute_error
# 16        NeuralNetFastAI_BAG_L1/4448b87a -18753.456261  mean_absolute_error
# 17  NeuralNetFastAI_BAG_L2/6d5d6101_Prune -18783.669923  mean_absolute_error
# 18        NeuralNetFastAI_BAG_L3/dee372fc -19046.318972  mean_absolute_error
# 19                     CatBoost_BAG_L3/T7 -19070.392811  mean_absolute_error
# 20                     CatBoost_BAG_L3/T3 -19072.613222  mean_absolute_error
# 21                     CatBoost_BAG_L2/T7 -19074.144185  mean_absolute_error
# 22                     CatBoost_BAG_L3/T8 -19076.184293  mean_absolute_error
# 23                     CatBoost_BAG_L3/T5 -19077.127190  mean_absolute_error
# 24                     CatBoost_BAG_L3/T4 -19077.256869  mean_absolute_error
# 25               CatBoost_BAG_L2/T3_Prune -19077.340297  mean_absolute_error
# 26                     CatBoost_BAG_L3/T6 -19078.205182  mean_absolute_error
# 27  NeuralNetFastAI_BAG_L1/d746ea00_Prune -19078.550589  mean_absolute_error
# 28               CatBoost_BAG_L2/T8_Prune -19080.086750  mean_absolute_error
# 29               CatBoost_BAG_L2/T6_Prune -19080.314838  mean_absolute_error
# 30               CatBoost_BAG_L2/T5_Prune -19081.364862  mean_absolute_error
# 31               CatBoost_BAG_L2/T4_Prune -19082.340622  mean_absolute_error
# 32                     CatBoost_BAG_L3/T1 -19084.627644  mean_absolute_error
# 33                     CatBoost_BAG_L2/T1 -19099.741129  mean_absolute_error
# 34                     CatBoost_BAG_L3/T2 -19103.659205  mean_absolute_error
# 35                     CatBoost_BAG_L2/T2 -19131.441284  mean_absolute_error
# 36  NeuralNetFastAI_BAG_L2/e17f26ee_Prune -19133.177552  mean_absolute_error
# 37  NeuralNetFastAI_BAG_L2/9bafefd8_Prune -19202.302147  mean_absolute_error
# 38               CatBoost_BAG_L1/T3_Prune -19443.652070  mean_absolute_error
# 39               CatBoost_BAG_L1/T1_Prune -19520.483122  mean_absolute_error
# 40        NeuralNetFastAI_BAG_L3/0d2d77ca -19539.592728  mean_absolute_error
# 41        NeuralNetFastAI_BAG_L3/bf250dcd -19542.688168  mean_absolute_error
# 42               CatBoost_BAG_L1/T2_Prune -19544.645353  mean_absolute_error
# 43                   LightGBMLarge_BAG_L1 -19690.641263  mean_absolute_error
# 44                   LightGBMLarge_BAG_L2 -19726.562693  mean_absolute_error
# 45                   LightGBMLarge_BAG_L3 -19811.860189  mean_absolute_error
# 46        NeuralNetFastAI_BAG_L3/38987d95 -20273.132246  mean_absolute_error
# 47                ExtraTrees_BAG_L2_Prune -21174.171692  mean_absolute_error
# 48                      ExtraTrees_BAG_L3 -21304.090900  mean_absolute_error
# 49                ExtraTrees_BAG_L1_Prune -21512.339855  mean_absolute_error
#
#     pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0       93.137936  8079.133357                0.002778           0.548741
# 1       22.817122  1703.293692                0.002323           0.425666
# 2        7.845421   561.044498                7.845421         561.044498
# 3       57.060124  5039.942585                0.002943           0.444527
# 4      101.701235  8693.593920                0.003186           0.372546
# 5       41.608279  3756.025792                4.255948         271.612895
# 6        6.523739   630.887675                6.523739         630.887675
# 7       44.414904  4061.978701                7.062573         577.565804
# 8       93.135158  8078.584615                2.688395         271.374838
# 9       41.481488  3821.797244                4.129158         337.384347
# 10       3.728278   281.800097                3.728278         281.800097
# 11      91.814052  7923.503298                1.367290         116.293521
# 12      41.609502  3852.935012                4.257171         368.522115
# 13      94.847455  8198.441753                4.400692         391.231976
# 14      93.241671  7914.321039                2.794909         107.111262
# 15      46.527546  3649.583020                9.175215         165.170123
# 16       4.717362   229.135757                4.717362         229.135757
# 17      40.844860  3569.253304                3.492529          84.840407
# 18      92.185906  7953.221578                1.739143         146.011801
# 19      91.055987  8246.171141                0.609224         438.961363
# 20      90.824653  7977.552860                0.377891         170.343082
# 21      38.132761  4244.499061                0.780430         760.086164
# 22      90.805862  7967.626666                0.359100         160.416889
# 23      90.744614  7936.183531                0.297852         128.973754
# 24      90.804624  8017.260919                0.357862         210.051142
# 25      37.719847  3761.553174                0.367516         277.140277
# 26      90.746318  7935.007670                0.299556         127.797893
# 27       3.996597   345.771802                3.996597         345.771802
# 28      37.689953  3724.297353                0.337622         239.884456
# 29      37.686059  3678.807252                0.333728         194.394355
# 30      37.630838  3704.734282                0.278507         220.321385
# 31      37.763945  3794.152803                0.411614         309.739906
# 32      90.676249  7884.333005                0.229487          77.123228
# 33      37.593966  3587.834673                0.241635         103.421776
# 34      90.623821  7839.655428                0.177059          32.445651
# 35      37.531499  3533.205047                0.179168          48.792150
# 36      44.642212  3747.650804                7.289881         263.237907
# 37      40.380703  3534.531921                3.028372          50.119024
# 38       1.270257   765.352148                1.270257         765.352148
# 39       0.706706   447.721792                0.706706         447.721792
# 40      99.212326  7904.157893                8.765564          96.948116
# 41      93.257684  8010.263293                2.810922         203.053515
# 42       0.466994   192.754017                0.466994         192.754017
# 43       2.596641     7.664411                2.596641           7.664411
# 44      38.733062  3492.706158                1.380731           8.293262
# 45      91.883255  7817.807231                1.436493          10.597453
# 46      93.821733  7827.079039                3.374970          19.869262
# 47      43.444963  3526.683424                6.092632          42.270527
# 48      97.671285  7881.917223                7.224523          74.707446
# 49       5.500337    22.280703                5.500337          22.280703
#
#     stack_level  can_infer  fit_order
# 0             4       True         49
# 1             2       True         11
# 2             1       True          9
# 3             3       True         30
# 4             4       True         50
# 5             2       True         16
# 6             1       True          8
# 7             2       True         17
# 8             3       True         44
# 9             2       True         28
# 10            1       True         10
# 11            3       True         42
# 12            2       True         25
# 13            3       True         40
# 14            3       True         45
# 15            2       True         15
# 16            1       True          1
# 17            2       True         29
# 18            3       True         43
# 19            3       True         37
# 20            3       True         33
# 21            2       True         14
# 22            3       True         38
# 23            3       True         35
# 24            3       True         34
# 25            2       True         19
# 26            3       True         36
# 27            1       True          7
# 28            2       True         23
# 29            2       True         22
# 30            2       True         21
# 31            2       True         20
# 32            3       True         31
# 33            2       True         12
# 34            3       True         32
# 35            2       True         13
# 36            2       True         27
# 37            2       True         26
# 38            1       True          5
# 39            1       True          3
# 40            3       True         46
# 41            3       True         41
# 42            1       True          4
# 43            1       True          2
# 44            2       True         18
# 45            3       True         48
# 46            3       True         47
# 47            2       True         24
# 48            3       True         39
# 49            1       True          6

# %% [markdown]
# ## **Submission**

# %%
leaderboard_test.head(10)
# Out:
#                                    model     score_val          eval_metric  \
# 0                WeightedEnsemble_ALL_L4 -17982.369702  mean_absolute_error
# 1                    WeightedEnsemble_L2 -18054.796327  mean_absolute_error
# 2  NeuralNetFastAI_BAG_L1/e0cb5511_Prune -18183.479282  mean_absolute_error
# 3                    WeightedEnsemble_L3 -18206.196820  mean_absolute_error
# 4                    WeightedEnsemble_L4 -18214.123080  mean_absolute_error
# 5        NeuralNetFastAI_BAG_L2/b293ca8b -18433.114924  mean_absolute_error
# 6  NeuralNetFastAI_BAG_L1/e213eaf9_Prune -18468.652920  mean_absolute_error
# 7        NeuralNetFastAI_BAG_L2/238d0081 -18480.180684  mean_absolute_error
# 8        NeuralNetFastAI_BAG_L3/091b55a8 -18486.213958  mean_absolute_error
# 9  NeuralNetFastAI_BAG_L2/dcee2eb7_Prune -18508.835151  mean_absolute_error
#
#    pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0      93.137936  8079.133357                0.002778           0.548741
# 1      22.817122  1703.293692                0.002323           0.425666
# 2       7.845421   561.044498                7.845421         561.044498
# 3      57.060124  5039.942585                0.002943           0.444527
# 4     101.701235  8693.593920                0.003186           0.372546
# 5      41.608279  3756.025792                4.255948         271.612895
# 6       6.523739   630.887675                6.523739         630.887675
# 7      44.414904  4061.978701                7.062573         577.565804
# 8      93.135158  8078.584615                2.688395         271.374838
# 9      41.481488  3821.797244                4.129158         337.384347
#
#    stack_level  can_infer  fit_order
# 0            4       True         49
# 1            2       True         11
# 2            1       True          9
# 3            3       True         30
# 4            4       True         50
# 5            2       True         16
# 6            1       True          8
# 7            2       True         17
# 8            3       True         44
# 9            2       True         28

# %%
WeightedEnsemble_ALL_L4 = submission.copy()
WeightedEnsemble_ALL_L4['price'] = predictor.predict(test_data, model='WeightedEnsemble_ALL_L4')
WeightedEnsemble_ALL_L4.to_csv(os.path.join(base_path, 'autogluon_MAE_WeightedEnsemble_ALL_L4.csv'), index=False)

# %%
WeightedEnsemble_L2 = submission.copy()
WeightedEnsemble_L2['price'] = predictor.predict(test_data, model='WeightedEnsemble_L2')
WeightedEnsemble_L2.to_csv(os.path.join(base_path, 'autogluon_MAE_WeightedEnsemble_L2.csv'), index=False)

# %%
NeuralNetFastAI_BAG_L1_Prune = submission.copy()
NeuralNetFastAI_BAG_L1_Prune['price'] = predictor.predict(test_data, model='NeuralNetFastAI_BAG_L1/e0cb5511_Prune')
NeuralNetFastAI_BAG_L1_Prune.to_csv(os.path.join(base_path, 'autogluon_MAE_NeuralNetFastAI_BAG_L1_Prune.csv'), index=False)

# %%
CatBoost_BAG_L3_T7 = submission.copy()
CatBoost_BAG_L3_T7['price'] = predictor.predict(test_data, model='CatBoost_BAG_L3/T7')
CatBoost_BAG_L3_T7.to_csv(os.path.join(base_path, 'autogluon_MAE_CatBoost_BAG_L3_T7.csv'), index=False)

# %%
#predictor.clone(os.path.join(base_path, "Autogluon/202409_MAE_train"))
# Out:
# Cloned TabularPredictor located in '/kaggle/working/Autogluon/202409_MAE_train' to '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MAE_train'.
# 	To load the cloned predictor: predictor_clone = TabularPredictor.load(path="/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MAE_train")
# '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MAE_train'

# %% [markdown]
# # **Autogluon MSE - MAE Training**

# %% [markdown]
# ## **Analizing outliers**

# %%
predictor_mse = TabularPredictor.load(os.path.join(base_path, "Autogluon/202409_20hr_train"))
predictor_mae = TabularPredictor.load(os.path.join(base_path, "Autogluon/202409_MAE_train"))

# %%
train['mse_price'] = predictor_mse.predict(train, model='WeightedEnsemble_L3')
train['mae_price'] = predictor_mae.predict(train, model='NeuralNetFastAI_BAG_L1/e0cb5511_Prune')
train['diff_price'] = train['mse_price'] - train['mae_price']
train['mse_mae_idx'] = train['mse_price'] / train['mae_price']

# %%
test['mse_price'] = predictor_mse.predict(test, model='WeightedEnsemble_L3')
test['mae_price'] = predictor_mae.predict(test, model='NeuralNetFastAI_BAG_L1/e0cb5511_Prune')
test['diff_price'] = test['mse_price'] - test['mae_price']
test['mse_mae_idx'] = test['mse_price'] / test['mae_price']

# %%
train['mse_squared_error'] = (train['price'] - train['mse_price'])**2
train = train.sort_values('mse_squared_error', ascending=False)
train['cumsum_error'] = train['mse_squared_error'].cumsum()
train['pct_cumsum_error'] = train['cumsum_error'] / train['mse_squared_error'].sum()
train = train.sort_values('pct_cumsum_error')
train['mse_mae_idx'] = train['mse_price'] / train['mae_price']
train['outlier'] = np.where(train['pct_cumsum_error'] <= 0.95, 1, 0)

# %%
# prompt: calculate the statistics of mse_mae_idx group by outlier
train.groupby('outlier')['mse_mae_idx'].agg(['mean', 'median', 'std', 'min', 'max'])
# Out:
#              mean    median       std       min       max
# outlier
# 0        1.057710  1.052996  0.133352  0.391522  8.020500
# 1        1.186414  1.156738  0.306516  0.569911  9.496945

# %%
stats = train.groupby('outlier')['mse_mae_idx'].agg(['mean', 'median', 'std', 'min', 'max']).T
stats['diff'] = stats[1] - stats[0]
stats
# Out:
# outlier         0         1      diff
# mean     1.057710  1.186414  0.128704
# median   1.052996  1.156738  0.103743
# std      0.133352  0.306516  0.173164
# min      0.391522  0.569911  0.178390
# max      8.020500  9.496945  1.476445

# %%
train.groupby('outlier').size()
# Out:
# outlier
# 0    185246
# 1      7296
# dtype: int64

# %%
from sklearn.metrics import mean_squared_error
import math

rmse_all = math.sqrt(mean_squared_error(train['price'], train['mse_price']))
print(f"RMSE All: {rmse_all}")
rmse = math.sqrt(mean_squared_error(train[train['outlier'] == 0]['price'], train[train['outlier'] == 0]['mse_price']))
print(f"RMSE without outliers: {rmse}")
# Out:
# RMSE All: 69620.81394374814
# RMSE without outliers: 15871.859058116876

# %% [markdown]
# ## **Training 12 hr**
#
# Will include new features from MSE and MAE.

# %%
train_mse_mae = train.copy()
train_mse_mae.drop(columns=['mse_squared_error',	'cumsum_error', 'pct_cumsum_error', 'outlier'], inplace=True)

# %%
from sklearn.model_selection import train_test_split
train_split, val_split = train_test_split(train_mse_mae, test_size=0.1, random_state=42)

# %%
# Setting up
eval_metric = 'rmse'
label = 'price'
problem_type='regression'
hours = 12

# Models to exclude
excluded_model_types = ['KNN']

# Initialize the TabularPredictor
predictor = TabularPredictor(label=label, eval_metric=eval_metric, problem_type=problem_type,
                             path = os.path.join(base_path, "Autogluon/202409_MSE_MAE_diff_train"))

# Fit the model
predictor.fit(
        train_data=train_split,
        time_limit=3600*hours,
        presets="best_quality",
        hyperparameters={
            'GBM': ['GBMLarge'],
            'XGB': {},
            'CAT': {},
            'XT': {},
            'FASTAI': {},
        },
        hyperparameter_tune_kwargs="auto",
        num_bag_folds=8,
        num_bag_sets=20,
        num_stack_levels=3,
        ag_args_ensemble={'use_orig_features': True},
        full_weighted_ensemble_additionally=True,
        feature_prune_kwargs={}
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          8
# Memory Avail:       36.59 GB / 50.99 GB (71.7%)
# Disk Space Avail:   162.38 GB / 225.83 GB (71.9%)
# ===================================================
# Presets specified: ['best_quality']
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=3, num_bag_folds=8, num_bag_sets=20
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 10800s of the 43200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-09-30 04:42:08,363	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho"
# (_dystack pid=262164) Running DyStack sub-fit ...
# (_dystack pid=262164) Beginning AutoGluon training ... Time limit = 10795s
# (_dystack pid=262164) AutoGluon will save models to "/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho"
# (_dystack pid=262164) Train Data Rows:    154032
# (_dystack pid=262164) Train Data Columns: 20
# (_dystack pid=262164) Label Column:       price
# (_dystack pid=262164) Problem Type:       regression
# (_dystack pid=262164) Preprocessing data ...
# (_dystack pid=262164) Using Feature Generators to preprocess the data ...
# (_dystack pid=262164) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=262164) 	Available Memory:                    26077.75 MB
# (_dystack pid=262164) 	Train Data (Original)  Memory Usage: 12.28 MB (0.0% of available memory)
# (_dystack pid=262164) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=262164) 	Stage 1 Generators:
# (_dystack pid=262164) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=262164) 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=262164) 	Stage 2 Generators:
# (_dystack pid=262164) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=262164) 	Stage 3 Generators:
# (_dystack pid=262164) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=262164) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=262164) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=262164) 	Stage 4 Generators:
# (_dystack pid=262164) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=262164) 	Stage 5 Generators:
# (_dystack pid=262164) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=262164) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=262164) 		('category', []) : 9 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# (_dystack pid=262164) 		('float', [])    : 7 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age', 'mse_price', 'mae_price', ...]
# (_dystack pid=262164) 		('int', [])      : 4 | ['model_year', 'milage', 'Vehicle_Age', 'Is_Luxury_Brand']
# (_dystack pid=262164) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=262164) 		('category', [])  : 8 | ['brand', 'model', 'fuel_type', 'engine', 'transmission', ...]
# (_dystack pid=262164) 		('float', [])     : 7 | ['Mileage_per_Year', 'milage_with_age', 'Mileage_per_Year_with_age', 'mse_price', 'mae_price', ...]
# (_dystack pid=262164) 		('int', [])       : 3 | ['model_year', 'milage', 'Vehicle_Age']
# (_dystack pid=262164) 		('int', ['bool']) : 2 | ['clean_title', 'Is_Luxury_Brand']
# (_dystack pid=262164) 	0.7s = Fit runtime
# (_dystack pid=262164) 	20 features in original data used to generate 20 features in processed data.
# (_dystack pid=262164) 	Train Data (Processed) Memory Usage: 11.17 MB (0.0% of available memory)
# (_dystack pid=262164) Data preprocessing and feature engineering runtime = 0.71s ...
# (_dystack pid=262164) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=262164) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=262164) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=262164) User-specified model hyperparameters to be fit:
# (_dystack pid=262164) {
# (_dystack pid=262164) 	'GBM': ['GBMLarge'],
# (_dystack pid=262164) 	'XGB': {},
# (_dystack pid=262164) 	'CAT': {},
# (_dystack pid=262164) 	'XT': {},
# (_dystack pid=262164) 	'FASTAI': {},
# (_dystack pid=262164) }
# (_dystack pid=262164) AutoGluon will fit 4 stack levels (L1 to L4) ...
# (_dystack pid=262164) Fitting 5 L1 models ...
# (_dystack pid=262164) Hyperparameter tuning model: CatBoost_BAG_L1 ... Tuning model for up to 647.51s of the 10794.49s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.38%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L1/T1 ...
# (_dystack pid=262164) 	-56817.3438	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	519.26s	 = Training   runtime
# (_dystack pid=262164) 	0.95s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: ExtraTrees_BAG_L1 ... Tuning model for up to 647.51s of the 10272.96s of remaining time.
# (_dystack pid=262164) 	No hyperparameter search space specified for ExtraTrees_BAG_L1. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=262164) Fitted model: ExtraTrees_BAG_L1 ...
# (_dystack pid=262164) 	-58442.8918	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	40.99s	 = Training   runtime
# (_dystack pid=262164) 	5.14s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: NeuralNetFastAI_BAG_L1 ... Tuning model for up to 647.51s of the 10231.78s of remaining time.
# (_dystack pid=262164) [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (_dystack pid=262164) ╭───────────────────────────────────────────────────────────╮
# (_dystack pid=262164) │ Configuration for experiment     NeuralNetFastAI_BAG_L1   │
# (_dystack pid=262164) ├───────────────────────────────────────────────────────────┤
# (_dystack pid=262164) │ Search algorithm                 SearchGenerator          │
# (_dystack pid=262164) │ Scheduler                        FIFOScheduler            │
# (_dystack pid=262164) │ Number of trials                 1000                     │
# (_dystack pid=262164) ╰───────────────────────────────────────────────────────────╯
# (_dystack pid=262164)
# (_dystack pid=262164) View detailed results here: /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1
# (_dystack pid=262164) Reached timeout of 647.5075974633229 seconds. Stopping all trials.
# (_dystack pid=262164) Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# (_dystack pid=262164) You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# (_dystack pid=262164) You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# (_dystack pid=262164) Wrote the latest version of all result files and experiment state to '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1' in 0.0396s.
# (_dystack pid=262164) Failed to fetch metrics for 6 trial(s):
# (_dystack pid=262164) - 43ad3006: FileNotFoundError('Could not fetch metrics for 43ad3006: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/43ad3006')
# (_dystack pid=262164) - 48c95d93: FileNotFoundError('Could not fetch metrics for 48c95d93: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/48c95d93')
# (_dystack pid=262164) - cf92a86d: FileNotFoundError('Could not fetch metrics for cf92a86d: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/cf92a86d')
# (_dystack pid=262164) - ebfe6e32: FileNotFoundError('Could not fetch metrics for ebfe6e32: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/ebfe6e32')
# (_dystack pid=262164) - 5543733f: FileNotFoundError('Could not fetch metrics for 5543733f: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/5543733f')
# (_dystack pid=262164) - 74aa74ef: FileNotFoundError('Could not fetch metrics for 74aa74ef: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L1/74aa74ef')
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L1/43ad3006 ...
# (_dystack pid=262164) 	-59978.6258	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	248.06s	 = Training   runtime
# (_dystack pid=262164) 	3.72s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L1/48c95d93 ...
# (_dystack pid=262164) 	-58981.2231	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	293.13s	 = Training   runtime
# (_dystack pid=262164) 	14.65s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L1/cf92a86d ...
# (_dystack pid=262164) 	-63266.9587	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	50.82s	 = Training   runtime
# (_dystack pid=262164) 	16.89s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L1/ebfe6e32 ...
# (_dystack pid=262164) 	-60204.4977	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	33.04s	 = Training   runtime
# (_dystack pid=262164) 	1.41s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: XGBoost_BAG_L1 ... Tuning model for up to 647.51s of the 9581.27s of remaining time.
# (_dystack pid=262164)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L1/T1 ...
# (_dystack pid=262164) 	-59588.7685	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	161.31s	 = Training   runtime
# (_dystack pid=262164) 	0.95s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L1/T2 ...
# (_dystack pid=262164) 	-59218.126	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	135.12s	 = Training   runtime
# (_dystack pid=262164) 	1.18s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L1/T3 ...
# (_dystack pid=262164) 	-59589.4474	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	281.12s	 = Training   runtime
# (_dystack pid=262164) 	5.66s	 = Validation runtime
# (_dystack pid=262164) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 647.51s of the 9003.35s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# (_dystack pid=262164) 	-58856.057	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	19.81s	 = Training   runtime
# (_dystack pid=262164) 	6.0s	 = Validation runtime
# (_dystack pid=262164) Insufficient time to train even a single feature pruning model (remaining: 0, needed: 19.805467128753662). Skipping feature pruning.
# (_dystack pid=262164) Completed 1/20 k-fold bagging repeats ...
# (_dystack pid=262164) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 8977.46s of remaining time.
# (_dystack pid=262164) 	Ensemble Weights: {'CatBoost_BAG_L1/T1': 0.522, 'ExtraTrees_BAG_L1': 0.174, 'NeuralNetFastAI_BAG_L1/48c95d93': 0.13, 'NeuralNetFastAI_BAG_L1/43ad3006': 0.087, 'LightGBMLarge_BAG_L1': 0.087}
# (_dystack pid=262164) 	-56202.5157	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	0.34s	 = Training   runtime
# (_dystack pid=262164) 	0.0s	 = Validation runtime
# (_dystack pid=262164) Fitting 5 L2 models ...
# (_dystack pid=262164) Hyperparameter tuning model: CatBoost_BAG_L2 ... Tuning model for up to 717.98s of the 8976.85s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.26%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L2/T1 ...
# (_dystack pid=262164) 	-56905.224	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	212.49s	 = Training   runtime
# (_dystack pid=262164) 	0.33s	 = Validation runtime
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L2/T2 ...
# (_dystack pid=262164) 	-57255.6759	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	52.68s	 = Training   runtime
# (_dystack pid=262164) 	0.18s	 = Validation runtime
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L2/T3 ...
# (_dystack pid=262164) 	-57190.9051	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	361.68s	 = Training   runtime
# (_dystack pid=262164) 	0.55s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: ExtraTrees_BAG_L2 ... Tuning model for up to 717.98s of the 8349.23s of remaining time.
# (_dystack pid=262164) 	No hyperparameter search space specified for ExtraTrees_BAG_L2. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=262164) Fitted model: ExtraTrees_BAG_L2 ...
# (_dystack pid=262164) 	-56558.2065	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	58.76s	 = Training   runtime
# (_dystack pid=262164) 	5.92s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: NeuralNetFastAI_BAG_L2 ... Tuning model for up to 717.98s of the 8290.27s of remaining time.
# (_dystack pid=262164) [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (_dystack pid=262164) ╭───────────────────────────────────────────────────────────╮
# (_dystack pid=262164) │ Configuration for experiment     NeuralNetFastAI_BAG_L2   │
# (_dystack pid=262164) ├───────────────────────────────────────────────────────────┤
# (_dystack pid=262164) │ Search algorithm                 SearchGenerator          │
# (_dystack pid=262164) │ Scheduler                        FIFOScheduler            │
# (_dystack pid=262164) │ Number of trials                 1000                     │
# (_dystack pid=262164) ╰───────────────────────────────────────────────────────────╯
# (_dystack pid=262164)
# (_dystack pid=262164) View detailed results here: /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2
# (_dystack pid=262164) Reached timeout of 717.9792926321554 seconds. Stopping all trials.
# (_dystack pid=262164) Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# (_dystack pid=262164) You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# (_dystack pid=262164) You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# (_dystack pid=262164) Wrote the latest version of all result files and experiment state to '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2' in 0.1589s.
# (_dystack pid=262164) Failed to fetch metrics for 5 trial(s):
# (_dystack pid=262164) - 6dc5b801: FileNotFoundError('Could not fetch metrics for 6dc5b801: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/6dc5b801')
# (_dystack pid=262164) - 467513d3: FileNotFoundError('Could not fetch metrics for 467513d3: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/467513d3')
# (_dystack pid=262164) - 9cb51e22: FileNotFoundError('Could not fetch metrics for 9cb51e22: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/9cb51e22')
# (_dystack pid=262164) - 2ae4ef2e: FileNotFoundError('Could not fetch metrics for 2ae4ef2e: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/2ae4ef2e')
# (_dystack pid=262164) - 8f7c6d98: FileNotFoundError('Could not fetch metrics for 8f7c6d98: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L2/8f7c6d98')
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L2/6dc5b801 ...
# (_dystack pid=262164) 	-56530.7781	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	319.76s	 = Training   runtime
# (_dystack pid=262164) 	3.69s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L2/467513d3 ...
# (_dystack pid=262164) 	-67919.8129	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	320.88s	 = Training   runtime
# (_dystack pid=262164) 	14.43s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L2/9cb51e22 ...
# (_dystack pid=262164) 	-56650.3394	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	55.36s	 = Training   runtime
# (_dystack pid=262164) 	2.74s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: XGBoost_BAG_L2 ... Tuning model for up to 717.98s of the 7569.38s of remaining time.
# (_dystack pid=262164)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.36%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.52%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L2/T1 ...
# (_dystack pid=262164) 	-58134.3226	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	52.02s	 = Training   runtime
# (_dystack pid=262164) 	0.65s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L2/T2 ...
# (_dystack pid=262164) 	-57823.1908	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	73.29s	 = Training   runtime
# (_dystack pid=262164) 	0.89s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L2/T3 ...
# (_dystack pid=262164) 	-58104.5562	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	133.41s	 = Training   runtime
# (_dystack pid=262164) 	1.7s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L2/T4 ...
# (_dystack pid=262164) 	-57039.8408	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	273.63s	 = Training   runtime
# (_dystack pid=262164) 	1.04s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L2/T5 ...
# (_dystack pid=262164) 	-59376.0407	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	46.23s	 = Training   runtime
# (_dystack pid=262164) 	0.9s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L2/T6 ...
# (_dystack pid=262164) 	-57571.4984	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	109.27s	 = Training   runtime
# (_dystack pid=262164) 	0.83s	 = Validation runtime
# (_dystack pid=262164) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 717.98s of the 6879.77s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=262164) 	-59033.9787	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	8.75s	 = Training   runtime
# (_dystack pid=262164) 	0.87s	 = Validation runtime
# (_dystack pid=262164) Insufficient time to train even a single feature pruning model (remaining: 0, needed: 8.747262954711914). Skipping feature pruning.
# (_dystack pid=262164) Completed 1/20 k-fold bagging repeats ...
# (_dystack pid=262164) Fitting model: WeightedEnsemble_L3 ... Training model for up to 398.88s of the 6868.05s of remaining time.
# (_dystack pid=262164) 	Ensemble Weights: {'ExtraTrees_BAG_L2': 0.333, 'NeuralNetFastAI_BAG_L2/6dc5b801': 0.267, 'NeuralNetFastAI_BAG_L2/9cb51e22': 0.2, 'XGBoost_BAG_L2/T4': 0.2}
# (_dystack pid=262164) 	-55393.5965	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	0.19s	 = Training   runtime
# (_dystack pid=262164) 	0.0s	 = Validation runtime
# (_dystack pid=262164) Fitting 5 L3 models ...
# (_dystack pid=262164) Hyperparameter tuning model: CatBoost_BAG_L3 ... Tuning model for up to 823.93s of the 6867.68s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.30%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.29%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L3/T1 ...
# (_dystack pid=262164) 	-57252.6398	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	322.47s	 = Training   runtime
# (_dystack pid=262164) 	0.3s	 = Validation runtime
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L3/T2 ...
# (_dystack pid=262164) 	-57123.674	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	81.0s	 = Training   runtime
# (_dystack pid=262164) 	0.21s	 = Validation runtime
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L3/T3 ...
# (_dystack pid=262164) 	-57553.5835	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	322.03s	 = Training   runtime
# (_dystack pid=262164) 	0.52s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: ExtraTrees_BAG_L3 ... Tuning model for up to 823.93s of the 6141.61s of remaining time.
# (_dystack pid=262164) 	No hyperparameter search space specified for ExtraTrees_BAG_L3. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=262164) Fitted model: ExtraTrees_BAG_L3 ...
# (_dystack pid=262164) 	-57436.531	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	65.21s	 = Training   runtime
# (_dystack pid=262164) 	5.94s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: NeuralNetFastAI_BAG_L3 ... Tuning model for up to 823.93s of the 6076.16s of remaining time.
# (_dystack pid=262164) [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (_dystack pid=262164) ╭───────────────────────────────────────────────────────────╮
# (_dystack pid=262164) │ Configuration for experiment     NeuralNetFastAI_BAG_L3   │
# (_dystack pid=262164) ├───────────────────────────────────────────────────────────┤
# (_dystack pid=262164) │ Search algorithm                 SearchGenerator          │
# (_dystack pid=262164) │ Scheduler                        FIFOScheduler            │
# (_dystack pid=262164) │ Number of trials                 1000                     │
# (_dystack pid=262164) ╰───────────────────────────────────────────────────────────╯
# (_dystack pid=262164)
# (_dystack pid=262164) View detailed results here: /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3
# (_dystack pid=262164) Reached timeout of 823.9286307168388 seconds. Stopping all trials.
# (_dystack pid=262164) Wrote the latest version of all result files and experiment state to '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3' in 0.0401s.
# (_dystack pid=262164) Failed to fetch metrics for 8 trial(s):
# (_dystack pid=262164) - 7242b410: FileNotFoundError('Could not fetch metrics for 7242b410: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/7242b410')
# (_dystack pid=262164) - b468bd60: FileNotFoundError('Could not fetch metrics for b468bd60: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/b468bd60')
# (_dystack pid=262164) - 36d1638e: FileNotFoundError('Could not fetch metrics for 36d1638e: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/36d1638e')
# (_dystack pid=262164) - 94b794ed: FileNotFoundError('Could not fetch metrics for 94b794ed: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/94b794ed')
# (_dystack pid=262164) - d9efafb2: FileNotFoundError('Could not fetch metrics for d9efafb2: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/d9efafb2')
# (_dystack pid=262164) - 5db035c3: FileNotFoundError('Could not fetch metrics for 5db035c3: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/5db035c3')
# (_dystack pid=262164) - 5bcda260: FileNotFoundError('Could not fetch metrics for 5bcda260: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/5bcda260')
# (_dystack pid=262164) - 331efd79: FileNotFoundError('Could not fetch metrics for 331efd79: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L3/331efd79')
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L3/7242b410 ...
# (_dystack pid=262164) 	-56068.1937	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	319.3s	 = Training   runtime
# (_dystack pid=262164) 	3.93s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L3/b468bd60 ...
# (_dystack pid=262164) 	-55964.9893	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	135.28s	 = Training   runtime
# (_dystack pid=262164) 	1.66s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L3/36d1638e ...
# (_dystack pid=262164) 	-55816.9652	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	108.09s	 = Training   runtime
# (_dystack pid=262164) 	1.89s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L3/94b794ed ...
# (_dystack pid=262164) 	-55214.93	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	199.19s	 = Training   runtime
# (_dystack pid=262164) 	3.16s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L3/d9efafb2 ...
# (_dystack pid=262164) 	-55925.8024	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	36.88s	 = Training   runtime
# (_dystack pid=262164) 	2.24s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: XGBoost_BAG_L3 ... Tuning model for up to 823.93s of the 5249.96s of remaining time.
# (_dystack pid=262164)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T1 ...
# (_dystack pid=262164) 	-58111.3079	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	70.41s	 = Training   runtime
# (_dystack pid=262164) 	0.76s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T2 ...
# (_dystack pid=262164) 	-57789.4667	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	100.16s	 = Training   runtime
# (_dystack pid=262164) 	1.0s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T3 ...
# (_dystack pid=262164) 	-58286.9531	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	152.93s	 = Training   runtime
# (_dystack pid=262164) 	1.84s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T4 ...
# (_dystack pid=262164) 	-57514.894	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	106.55s	 = Training   runtime
# (_dystack pid=262164) 	0.78s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T5 ...
# (_dystack pid=262164) 	-59269.8663	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	47.63s	 = Training   runtime
# (_dystack pid=262164) 	0.93s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T6 ...
# (_dystack pid=262164) 	-57852.8979	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	90.95s	 = Training   runtime
# (_dystack pid=262164) 	0.71s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T7 ...
# (_dystack pid=262164) 	-58634.5739	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	151.78s	 = Training   runtime
# (_dystack pid=262164) 	2.32s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L3/T8 ...
# (_dystack pid=262164) 	-57780.4617	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	66.89s	 = Training   runtime
# (_dystack pid=262164) 	0.87s	 = Validation runtime
# (_dystack pid=262164) Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 823.93s of the 4461.62s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# (_dystack pid=262164) 	-59156.6931	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	7.74s	 = Training   runtime
# (_dystack pid=262164) 	0.6s	 = Validation runtime
# (_dystack pid=262164) Insufficient time to train even a single feature pruning model (remaining: 0, needed: 7.7386627197265625). Skipping feature pruning.
# (_dystack pid=262164) Completed 1/20 k-fold bagging repeats ...
# (_dystack pid=262164) Fitting model: WeightedEnsemble_L4 ... Training model for up to 457.74s of the 4450.94s of remaining time.
# (_dystack pid=262164) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L3/94b794ed': 0.619, 'NeuralNetFastAI_BAG_L3/7242b410': 0.143, 'NeuralNetFastAI_BAG_L3/b468bd60': 0.095, 'NeuralNetFastAI_BAG_L3/d9efafb2': 0.095, 'CatBoost_BAG_L3/T2': 0.048}
# (_dystack pid=262164) 	-55037.2074	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	0.29s	 = Training   runtime
# (_dystack pid=262164) 	0.0s	 = Validation runtime
# (_dystack pid=262164) Fitting 5 L4 models ...
# (_dystack pid=262164) Hyperparameter tuning model: CatBoost_BAG_L4 ... Tuning model for up to 801.1s of the 4450.4s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.34%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.33%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.43%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L4/T1 ...
# (_dystack pid=262164) 	-57488.5031	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	184.81s	 = Training   runtime
# (_dystack pid=262164) 	0.36s	 = Validation runtime
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L4/T2 ...
# (_dystack pid=262164) 	-57307.3643	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	82.01s	 = Training   runtime
# (_dystack pid=262164) 	0.2s	 = Validation runtime
# (_dystack pid=262164) Fitted model: CatBoost_BAG_L4/T3 ...
# (_dystack pid=262164) 	-57388.4008	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	426.77s	 = Training   runtime
# (_dystack pid=262164) 	0.45s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: ExtraTrees_BAG_L4 ... Tuning model for up to 801.1s of the 3756.19s of remaining time.
# (_dystack pid=262164) 	No hyperparameter search space specified for ExtraTrees_BAG_L4. Skipping HPO. Will train one model based on the provided hyperparameters.
# (_dystack pid=262164) Fitted model: ExtraTrees_BAG_L4 ...
# (_dystack pid=262164) 	-57146.6087	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	74.31s	 = Training   runtime
# (_dystack pid=262164) 	6.65s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: NeuralNetFastAI_BAG_L4 ... Tuning model for up to 801.1s of the 3680.3s of remaining time.
# (_dystack pid=262164) [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (_dystack pid=262164) ╭───────────────────────────────────────────────────────────╮
# (_dystack pid=262164) │ Configuration for experiment     NeuralNetFastAI_BAG_L4   │
# (_dystack pid=262164) ├───────────────────────────────────────────────────────────┤
# (_dystack pid=262164) │ Search algorithm                 SearchGenerator          │
# (_dystack pid=262164) │ Scheduler                        FIFOScheduler            │
# (_dystack pid=262164) │ Number of trials                 1000                     │
# (_dystack pid=262164) ╰───────────────────────────────────────────────────────────╯
# (_dystack pid=262164)
# (_dystack pid=262164) View detailed results here: /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4
# (_dystack pid=262164) Reached timeout of 801.1011560153961 seconds. Stopping all trials.
# (_dystack pid=262164) Wrote the latest version of all result files and experiment state to '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4' in 0.1855s.
# (_dystack pid=262164) Failed to fetch metrics for 5 trial(s):
# (_dystack pid=262164) - 931a472d: FileNotFoundError('Could not fetch metrics for 931a472d: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4/931a472d')
# (_dystack pid=262164) - fcd8d45d: FileNotFoundError('Could not fetch metrics for fcd8d45d: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4/fcd8d45d')
# (_dystack pid=262164) - 309bbeed: FileNotFoundError('Could not fetch metrics for 309bbeed: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4/309bbeed')
# (_dystack pid=262164) - bba2eb4b: FileNotFoundError('Could not fetch metrics for bba2eb4b: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4/bba2eb4b')
# (_dystack pid=262164) - 9d066755: FileNotFoundError('Could not fetch metrics for 9d066755: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/ds_sub_fit/sub_fit_ho/models/NeuralNetFastAI_BAG_L4/9d066755')
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L4/931a472d ...
# (_dystack pid=262164) 	-55756.3024	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	311.47s	 = Training   runtime
# (_dystack pid=262164) 	3.85s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L4/fcd8d45d ...
# (_dystack pid=262164) 	-55307.6424	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	370.07s	 = Training   runtime
# (_dystack pid=262164) 	7.77s	 = Validation runtime
# (_dystack pid=262164) Fitted model: NeuralNetFastAI_BAG_L4/309bbeed ...
# (_dystack pid=262164) 	-55582.8428	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	87.93s	 = Training   runtime
# (_dystack pid=262164) 	4.47s	 = Validation runtime
# (_dystack pid=262164) Hyperparameter tuning model: XGBoost_BAG_L4 ... Tuning model for up to 801.1s of the 2868.36s of remaining time.
# (_dystack pid=262164)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.48%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.65%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.44%)
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.53%)
# (_dystack pid=262164) 	Stopping HPO to satisfy time limit...
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T1 ...
# (_dystack pid=262164) 	-58263.8721	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	62.09s	 = Training   runtime
# (_dystack pid=262164) 	0.78s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T2 ...
# (_dystack pid=262164) 	-58317.842	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	71.14s	 = Training   runtime
# (_dystack pid=262164) 	0.76s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T3 ...
# (_dystack pid=262164) 	-58599.275	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	146.5s	 = Training   runtime
# (_dystack pid=262164) 	1.98s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T4 ...
# (_dystack pid=262164) 	-57558.1809	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	89.01s	 = Training   runtime
# (_dystack pid=262164) 	0.73s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T5 ...
# (_dystack pid=262164) 	-59928.1324	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	54.21s	 = Training   runtime
# (_dystack pid=262164) 	0.99s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T6 ...
# (_dystack pid=262164) 	-57629.3548	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	125.22s	 = Training   runtime
# (_dystack pid=262164) 	0.84s	 = Validation runtime
# (_dystack pid=262164) Fitted model: XGBoost_BAG_L4/T7 ...
# (_dystack pid=262164) 	-58272.5024	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	178.37s	 = Training   runtime
# (_dystack pid=262164) 	2.74s	 = Validation runtime
# (_dystack pid=262164) Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 801.1s of the 2140.75s of remaining time.
# (_dystack pid=262164) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.37%)
# (_dystack pid=262164) 	-58630.2972	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	15.06s	 = Training   runtime
# (_dystack pid=262164) 	1.05s	 = Validation runtime
# (_dystack pid=262164) Insufficient time to train even a single feature pruning model (remaining: 0, needed: 15.059819221496582). Skipping feature pruning.
# (_dystack pid=262164) Completed 1/20 k-fold bagging repeats ...
# (_dystack pid=262164) Fitting model: WeightedEnsemble_ALL_L5 ... Training model for up to 445.06s of the 2121.74s of remaining time.
# (_dystack pid=262164) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L3/94b794ed': 0.417, 'NeuralNetFastAI_BAG_L4/fcd8d45d': 0.333, 'ExtraTrees_BAG_L2': 0.167, 'CatBoost_BAG_L1/T1': 0.042, 'NeuralNetFastAI_BAG_L4/309bbeed': 0.042}
# (_dystack pid=262164) 	-54868.8063	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=262164) 	0.31s	 = Training   runtime
# (_dystack pid=262164) 	0.0s	 = Validation runtime
# ...
# 	533.4s	 = Training   runtime
# 	17.07s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 2646.31s of the 14277.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.49%)
# 	-57832.5492	 = Validation score   (-root_mean_squared_error)
# 	12.55s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Insufficient time to train even a single feature pruning model (remaining: 0, needed: 12.549662590026855). Skipping feature pruning.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 1470.17s of the 14261.91s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L3/cb0a7cc5': 0.429, 'NeuralNetFastAI_BAG_L3/efa81922': 0.143, 'NeuralNetFastAI_BAG_L3/71cb5f01': 0.143, 'NeuralNetFastAI_BAG_L3/ffea7463': 0.095, 'NeuralNetFastAI_BAG_L3/c773cf7e': 0.095, 'CatBoost_BAG_L3/T3': 0.048, 'ExtraTrees_BAG_L3': 0.048}
# 	-54251.7668	 = Validation score   (-root_mean_squared_error)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 5 L4 models ...
# Hyperparameter tuning model: CatBoost_BAG_L4 ... Tuning model for up to 2567.08s of the 14261.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	Stopping HPO to satisfy time limit...
# Fitted model: CatBoost_BAG_L4/T1 ...
# 	-56731.6336	 = Validation score   (-root_mean_squared_error)
# 	372.81s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitted model: CatBoost_BAG_L4/T2 ...
# 	-56710.8154	 = Validation score   (-root_mean_squared_error)
# 	87.82s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitted model: CatBoost_BAG_L4/T3 ...
# 	-57082.8992	 = Validation score   (-root_mean_squared_error)
# 	648.43s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitted model: CatBoost_BAG_L4/T4 ...
# 	-56937.229	 = Validation score   (-root_mean_squared_error)
# 	1166.89s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Hyperparameter tuning model: ExtraTrees_BAG_L4 ... Tuning model for up to 2567.08s of the 11984.28s of remaining time.
# 	No hyperparameter search space specified for ExtraTrees_BAG_L4. Skipping HPO. Will train one model based on the provided hyperparameters.
# Fitted model: ExtraTrees_BAG_L4 ...
# 	-56115.1771	 = Validation score   (-root_mean_squared_error)
# 	109.58s	 = Training   runtime
# 	9.46s	 = Validation runtime
# Hyperparameter tuning model: NeuralNetFastAI_BAG_L4 ... Tuning model for up to 2567.08s of the 11874.24s of remaining time.
# 2024-09-30 13:24:11,077	INFO tune.py:622 -- [output] This will use the new output engine with verbosity 0. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# +-----------------------------------------------------------+
# | Configuration for experiment     NeuralNetFastAI_BAG_L4   |
# +-----------------------------------------------------------+
# | Search algorithm                 SearchGenerator          |
# | Scheduler                        FIFOScheduler            |
# | Number of trials                 1000                     |
# +-----------------------------------------------------------+
#
# View detailed results here: /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4
# 2024-09-30 14:06:58,390	INFO timeout.py:54 -- Reached timeout of 2567.077212138176 seconds. Stopping all trials.
# 2024-09-30 14:06:58,454	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to '/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4' in 0.0539s.
# 2024-09-30 14:07:08,562	WARNING experiment_analysis.py:190 -- Failed to fetch metrics for 14 trial(s):
# - 2d8f5f74: FileNotFoundError('Could not fetch metrics for 2d8f5f74: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/2d8f5f74')
# - 9d349a0f: FileNotFoundError('Could not fetch metrics for 9d349a0f: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/9d349a0f')
# - 626677e8: FileNotFoundError('Could not fetch metrics for 626677e8: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/626677e8')
# - 197d86d0: FileNotFoundError('Could not fetch metrics for 197d86d0: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/197d86d0')
# - d264a2d3: FileNotFoundError('Could not fetch metrics for d264a2d3: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/d264a2d3')
# - ae3ce58d: FileNotFoundError('Could not fetch metrics for ae3ce58d: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/ae3ce58d')
# - 81916fa5: FileNotFoundError('Could not fetch metrics for 81916fa5: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/81916fa5')
# - 45e5f9a9: FileNotFoundError('Could not fetch metrics for 45e5f9a9: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/45e5f9a9')
# - cff97826: FileNotFoundError('Could not fetch metrics for cff97826: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/cff97826')
# - 7a032428: FileNotFoundError('Could not fetch metrics for 7a032428: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/7a032428')
# - dba66466: FileNotFoundError('Could not fetch metrics for dba66466: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/dba66466')
# - ab427ae4: FileNotFoundError('Could not fetch metrics for ab427ae4: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/ab427ae4')
# - 82a64a38: FileNotFoundError('Could not fetch metrics for 82a64a38: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/82a64a38')
# - 7d4ced27: FileNotFoundError('Could not fetch metrics for 7d4ced27: both result.json and progress.csv were not found at /content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train/models/NeuralNetFastAI_BAG_L4/7d4ced27')
# Fitted model: NeuralNetFastAI_BAG_L4/2d8f5f74 ...
# 	-54923.305	 = Validation score   (-root_mean_squared_error)
# 	393.55s	 = Training   runtime
# 	4.64s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/9d349a0f ...
# 	-55010.1857	 = Validation score   (-root_mean_squared_error)
# 	82.6s	 = Training   runtime
# 	3.11s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/626677e8 ...
# 	-54841.2086	 = Validation score   (-root_mean_squared_error)
# 	650.03s	 = Training   runtime
# 	6.92s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/197d86d0 ...
# 	-55364.0882	 = Validation score   (-root_mean_squared_error)
# 	238.53s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/d264a2d3 ...
# 	-54469.2591	 = Validation score   (-root_mean_squared_error)
# 	62.64s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/ae3ce58d ...
# 	-54915.981	 = Validation score   (-root_mean_squared_error)
# 	176.03s	 = Training   runtime
# 	9.91s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/81916fa5 ...
# 	-54592.6696	 = Validation score   (-root_mean_squared_error)
# 	75.18s	 = Training   runtime
# 	1.79s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/45e5f9a9 ...
# 	-55298.1103	 = Validation score   (-root_mean_squared_error)
# 	249.71s	 = Training   runtime
# 	7.68s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/cff97826 ...
# 	-55071.1257	 = Validation score   (-root_mean_squared_error)
# 	188.19s	 = Training   runtime
# 	3.21s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/7a032428 ...
# 	-54594.0014	 = Validation score   (-root_mean_squared_error)
# 	100.33s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/dba66466 ...
# 	-54838.7573	 = Validation score   (-root_mean_squared_error)
# 	245.8s	 = Training   runtime
# 	8.18s	 = Validation runtime
# Fitted model: NeuralNetFastAI_BAG_L4/ab427ae4 ...
# 	-55811.4453	 = Validation score   (-root_mean_squared_error)
# 	44.89s	 = Training   runtime
# 	6.95s	 = Validation runtime
# Hyperparameter tuning model: XGBoost_BAG_L4 ... Tuning model for up to 2567.08s of the 9295.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.54%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.87%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	Stopping HPO to satisfy time limit...
# Fitted model: XGBoost_BAG_L4/T1 ...
# 	-57721.968	 = Validation score   (-root_mean_squared_error)
# 	144.59s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T2 ...
# 	-57746.5415	 = Validation score   (-root_mean_squared_error)
# 	83.05s	 = Training   runtime
# 	1.08s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T3 ...
# 	-58155.87	 = Validation score   (-root_mean_squared_error)
# 	168.56s	 = Training   runtime
# 	2.23s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T4 ...
# 	-57349.1429	 = Validation score   (-root_mean_squared_error)
# 	119.44s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T5 ...
# 	-58821.0523	 = Validation score   (-root_mean_squared_error)
# 	62.95s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T6 ...
# 	-57282.7302	 = Validation score   (-root_mean_squared_error)
# 	138.54s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T7 ...
# 	-58169.0867	 = Validation score   (-root_mean_squared_error)
# 	242.66s	 = Training   runtime
# 	2.74s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T8 ...
# 	-57446.2953	 = Validation score   (-root_mean_squared_error)
# 	91.95s	 = Training   runtime
# 	1.08s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T9 ...
# 	-57317.968	 = Validation score   (-root_mean_squared_error)
# 	192.48s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T10 ...
# 	-57593.765	 = Validation score   (-root_mean_squared_error)
# 	139.56s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T11 ...
# 	-57571.8843	 = Validation score   (-root_mean_squared_error)
# 	945.96s	 = Training   runtime
# 	4.56s	 = Validation runtime
# Fitted model: XGBoost_BAG_L4/T12 ...
# 	-60589.5753	 = Validation score   (-root_mean_squared_error)
# 	188.78s	 = Training   runtime
# 	5.82s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L4 ... Training model for up to 2567.08s of the 6774.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.51%)
# 	-58351.1615	 = Validation score   (-root_mean_squared_error)
# 	12.14s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Insufficient time to train even a single feature pruning model (remaining: 0, needed: 12.141093730926514). Skipping feature pruning.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_ALL_L5 ... Training model for up to 1426.15s of the 6757.25s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L3/cb0a7cc5': 0.32, 'NeuralNetFastAI_BAG_L4/d264a2d3': 0.24, 'NeuralNetFastAI_BAG_L4/7a032428': 0.24, 'CatBoost_BAG_L1/T1': 0.04, 'CatBoost_BAG_L2/T2': 0.04, 'LightGBMLarge_BAG_L2': 0.04, 'NeuralNetFastAI_BAG_L3/ffea7463': 0.04, 'NeuralNetFastAI_BAG_L4/81916fa5': 0.04}
# 	-54189.3498	 = Validation score   (-root_mean_squared_error)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L5 ... Training model for up to 1426.15s of the 6756.6s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L4/7a032428': 0.273, 'NeuralNetFastAI_BAG_L4/d264a2d3': 0.227, 'NeuralNetFastAI_BAG_L4/dba66466': 0.227, 'NeuralNetFastAI_BAG_L4/626677e8': 0.182, 'NeuralNetFastAI_BAG_L4/81916fa5': 0.091}
# 	-54238.1701	 = Validation score   (-root_mean_squared_error)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 27646.06s ... Best model: WeightedEnsemble_ALL_L5 | Estimated inference throughput: 89.0 rows/s (21661 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/drive/MyDrive/DS_Projects/Playground_Series/ps4s9_Regression_Use_Cars/Data/Autogluon/202409_MSE_MAE_diff_train")

# %%
predictor = TabularPredictor.load(os.path.join(base_path, "Autogluon/202409_MSE_MAE_diff_train"))

# %%
leaderboard_test = predictor.leaderboard(val_split)
leaderboard_test

# %%
leaderboard_test.sort_values('score_val', ascending=False).head(10)

# %%
sub_NeuralNetFastAI_BAG_L3 = submission.copy()
sub_NeuralNetFastAI_BAG_L3['price'] = predictor.predict(test, model='NeuralNetFastAI_BAG_L3/cb0a7cc5')
sub_NeuralNetFastAI_BAG_L3.to_csv(os.path.join(base_path, 'autogluon_MSE_Idx_NeuralNetFastAI_BAG_L3.csv'), index=False)

# %%
sub_WeightedEnsemble_ALL_L5 = submission.copy()
sub_WeightedEnsemble_ALL_L5['price'] = predictor.predict(test, model='WeightedEnsemble_ALL_L5')
sub_WeightedEnsemble_ALL_L5.to_csv(os.path.join(base_path, 'autogluon_MSE_Idx_WeightedEnsemble_ALL_L5.csv'), index=False)
